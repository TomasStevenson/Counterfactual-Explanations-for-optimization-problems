# %% [markdown]
# # Branch-and-Sandwich — Mutable Line Limits
# ## Applied to 6-bus, IEEE 14-bus, IEEE 30-bus, IEEE 39-bus, IEEE 57-bus, IEEE 118-bus, IEEE 300-bus
#
# **Algorithm:** Branch-and-Sandwich WCE (Weakly Counterfactual Explanation)
# **Mutable parameter:** Line flow limits (`b` vector / `fmax`)
# **Foil:** Emissions reduction by α = 20 %
# **Special case (6-bus):** also run with a commitment-flip foil for comparison
#
# **Structure**
# - Section 0 — Imports and helpers
# - Section 1 — Dataset loading
# - Section 2 — Factual UC solve and emissions baseline per grid
# - Section 3 — Branch-and-Sandwich for each grid with plots
# - Section 4 — Cross-grid comparison

# %% [markdown]
# ## 0 · Imports and helpers

# %%
import os, importlib, warnings
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.gridspec as gridspec
from dataclasses import replace
from typing import Optional, Callable, Dict, Tuple

import gurobipy as gp
from gurobipy import GRB

os.environ["GRB_LICENSE_FILE"] = r"C:\Users\tomas\Desktop\gurobi.lic"

import uc_pipeline, uc_data_loader, uc_branch_sandwich_4b, uc_master_relax_4b
importlib.reload(uc_pipeline)
importlib.reload(uc_data_loader)
importlib.reload(uc_branch_sandwich_4b)
importlib.reload(uc_master_relax_4b)

from uc_pipeline import (
    NetworkUCData, IndexMap,
    build_index_map_network_uc,
    build_cost_vector_network_uc,
    default_initial_conditions,
    solve_uc_with_cost_4b,
    make_emissions_foil_4b,
)
from uc_data_loader import quick_setup
from uc_branch_sandwich_4b import UCBranchAndSandwichWCE_4b

# ── Data folder ───────────────────────────────────────────────────────────
DATA_DIR = r"C:\Users\tomas\Documents\GitHub\Counterfactual-Explanations-for-optimization-problems\Mixed\UC-Experiments\Data"

ALPHA     = 0.10   # emissions reduction target
UTIL_THR  = 0.75   # congestion threshold: lines with utilisation >= this are mutable
maxnodes  = 1500   # maximum number of nodes in branch-and-sandwich tree
warnings.filterwarnings("ignore")
print("Imports OK")
print(f"Data directory: {DATA_DIR}")
print(f"Emissions reduction alpha = {ALPHA:.0%}  |  Congestion threshold = {UTIL_THR:.0%}")
# Out:
# Imports OK
# Data directory: C:\Users\tomas\Documents\GitHub\Counterfactual-Explanations-for-optimization-problems\Mixed\UC-Experiments\Data
# Emissions reduction alpha = 10%  |  Congestion threshold = 75%

# %% [markdown]
# ### Oracle, line-limit helpers and plotting utilities

# %%
# ── replace_line_limits ──────────────────────────────────────────────────
def replace_line_limits(data: NetworkUCData, b_line: np.ndarray) -> NetworkUCData:
    b_line = np.asarray(b_line, dtype=float).reshape(-1)
    assert len(b_line) == len(data.lines)
    new_lines = [replace(L, fmax=float(b_line[ell])) for ell, L in enumerate(data.lines)]
    return replace(data, lines=new_lines)


# ── make_line_weights ─────────────────────────────────────────────────────
def make_line_weights(DATA, b0, util=None, alpha=1.0, beta=1.0, gamma=0.5, eps_u=0.05):
    """
    Weights based on reactance proxy, original limit, and inverse utilisation.
    Normalised to mean 1 and clipped to [0.1, 10].
    """
    b_susc  = np.array([float(L.b) for L in DATA.lines], dtype=float)
    x_proxy = 1.0 / np.maximum(np.abs(b_susc), 1e-9)
    x_med   = np.median(x_proxy)
    b0_med  = np.median(b0)
    w = (x_proxy / max(x_med, 1e-9))**alpha * (b0 / max(b0_med, 1e-9))**beta
    if util is not None:
        w *= (1.0 / (eps_u + util))**gamma
    w = w / np.mean(w)
    w = np.clip(w, 0.1, 10.0)
    return w


# ── congestion-threshold free lines ─────────────────────────────────────
def get_congested_free_lines(sol0, b0, thr=0.75):
    """
    Return indices of all lines whose peak utilisation >= thr in the factual sol.
    Falls back to the single most-utilised line if none exceed the threshold.
    """
    f_abs_max = np.max(np.abs(sol0["f"]), axis=1)     # (nL,)
    util      = f_abs_max / np.maximum(b0, 1e-9)
    idx_cong  = [ell for ell in range(len(b0)) if util[ell] >= thr]
    if len(idx_cong) == 0:
        idx_cong = [int(np.argmax(util))]  # safe fallback
    return idx_cong, util


# ── build b-bounds ────────────────────────────────────────────────────────
def build_b_bounds(b0, b_free_idx, scale_up=5.0):
    """Lower bound = b0 (no tightening), upper bound = scale_up * b0."""
    bL = b0.copy()
    bU = b0.copy()
    for ell in b_free_idx:
        bU[ell] = scale_up * b0[ell]
    return bL, bU


# ── UCWeakWCEOracle ───────────────────────────────────────────────────────
class UCWeakWCEOracle:
    def __init__(self, data, cvec, idx, window_size, per_bus_neutrality,
                 u_init, p_init, on_t, off_t,
                 foil_extra_constr_fn=None,
                 output_flag=0, time_limit=None, cache_decimals=3):
        self.data               = data
        self.cvec               = np.asarray(cvec, float)
        self.idx                = idx
        self.window_size        = int(window_size)
        self.per_bus_neutrality = bool(per_bus_neutrality)
        self.u_init = u_init; self.p_init = p_init
        self.on_t   = on_t;   self.off_t  = off_t
        self.foil_extra_constr_fn = foil_extra_constr_fn
        self.output_flag  = int(output_flag)
        self.time_limit   = time_limit
        self.cache_decimals = int(cache_decimals)
        self.cache_plain  = {}
        self.cache_foil   = {}

    def _key(self, b_line):
        return tuple(np.round(np.asarray(b_line, float), self.cache_decimals))

    def _solve(self, b_line, extra_fn, cache):
        key = self._key(b_line)
        if key in cache:
            return cache[key]
        data_b = replace_line_limits(self.data, b_line)
        m, sol, z = solve_uc_with_cost_4b(
            data=data_b, idx=self.idx, cvec=self.cvec,
            window_size=self.window_size,
            per_bus_neutrality=self.per_bus_neutrality,
            u_init=self.u_init, p_init=self.p_init,
            on_time_init=self.on_t, off_time_init=self.off_t,
            extra_constr_fn=extra_fn,
            output_flag=self.output_flag,
            time_limit=self.time_limit,
            fmax_override=None,
        )
        out = (None, None, None) if sol is None else (float(sol["obj"]), np.array(z, float), sol)
        cache[key] = out
        return out

    def solve_plain(self, b_line):
        return self._solve(b_line, None, self.cache_plain)

    def solve_foil(self, b_line):
        return self._solve(b_line, self.foil_extra_constr_fn, self.cache_foil)


# ── Foil helpers (commitment-flip, used only for 6-bus bonus experiment) ─
def _as_list(x):
    if x is None: return []
    return list(x) if isinstance(x, (list, tuple, set)) else [x]

def _get_var(var, names):
    for n in names:
        if isinstance(var, dict) and n in var: return var[n]
        if hasattr(var, n): return getattr(var, n)
    raise KeyError(f"Could not find any of {names}")

def foil_force_on(g, times):
    times = _as_list(times)
    def _f(m, var, *a, **k):
        u = _get_var(var, ["u", "U"])
        for t in times:
            m.addConstr(u[g, t] == 1, name=f"foil_on_g{g}_t{t}")
    return _f

def foil_force_off(g, times):
    times = _as_list(times)
    def _f(m, var, *a, **k):
        u = _get_var(var, ["u", "U"])
        for t in times:
            m.addConstr(u[g, t] == 0, name=f"foil_off_g{g}_t{t}")
    return _f

def scan_foil_candidates(data, idx, cvec, solF, zF,
                         window_size, per_bus_neutrality,
                         u_init, p_init, on_t, off_t,
                         min_gap=100, max_gap=1e7, block_len_range=(2, 4)):
    nG = len(data.gens)
    T  = int(data.T)
    factual_obj = float(np.dot(cvec, zF))
    candidates  = []
    print(f"Scanning foil candidates  (factual obj={factual_obj:.0f})")
    print(f"  g  times             gap    type  verdict")
    print("  " + "-"*55)
    def get_blocks(hrs):
        blocks = []
        if hrs:
            s = p = hrs[0]
            for t in hrs[1:]:
                if t != p+1: blocks.append((s, p)); s = t
                p = t
            blocks.append((s, p))
        return blocks
    for g in range(nG):
        gen = data.gens[g]
        if gen.UT > 1 or gen.DT > 1: continue
        uF_g    = solF["u"][g]
        on_hrs  = [t for t in range(T) if int(round(uF_g[t])) == 1]
        off_hrs = [t for t in range(T) if int(round(uF_g[t])) == 0]
        for (t0, t1), ftype in ([(b, "ON")  for b in get_blocks(off_hrs)] +
                                 [(b, "OFF") for b in get_blocks(on_hrs)]):
            for L in range(block_len_range[0], block_len_range[1]+1):
                if t0+L-1 > t1: continue
                times = list(range(t0, t0+L))
                foil  = foil_force_on(g, times) if ftype == "ON" else foil_force_off(g, times)
                _, solT, zT = solve_uc_with_cost_4b(
                    data=data, idx=idx, cvec=cvec,
                    window_size=window_size, per_bus_neutrality=per_bus_neutrality,
                    u_init=u_init, p_init=p_init,
                    on_time_init=on_t, off_time_init=off_t,
                    extra_constr_fn=foil, output_flag=0,
                )
                if solT is None: continue
                gap     = float(np.dot(cvec, zT)) - factual_obj
                ok      = min_gap < gap < max_gap
                verdict = "good" if ok else ("trivial" if gap <= min_gap else "too large")
                print(f"  g={g}  t={str(times):>15}  {gap:>8.0f}  {ftype:>4}  {verdict}")
                if ok: candidates.append((gap, g, times, ftype))
    candidates.sort()
    if candidates:
        print(f"\n  Best: G{candidates[0][1]} {candidates[0][3]} "
              f"t={candidates[0][2]} gap={candidates[0][0]:.0f}")
    else:
        print("\n  No good candidates found.")
    return candidates


TECH_COLORS = ["#73726c","#378ADD","#BA7517","#7F77DD","#1D9E75",
               "#D85A30","#639922","#5DCAA5","#EF9F27","#E24B4A"]

print("Helpers defined.")
# Out:
# Helpers defined.

# %% [markdown]
# ### Plot function — `plot_bs_results`

# %%
def plot_bs_results(DATA, b0, b_hat, sol0, sol_plain_hat, sol_foil_hat,
                    res_bs, label="", foil_label="emissions −20%"):
    """
    Unified B&S results figure.  Four panels per grid:
      (1) Factual dispatch         (2) Counterfactual dispatch
      (3) Curtailment comparison   (4) Line-limit changes (per-unit b_hat / b0)
    Plus a summary print block.
    """
    if res_bs is None or not res_bs.get("success"):
        print(f"[{label}] No successful result — nothing to plot.")
        return

    nG = len(DATA.gens)
    nR = len(DATA.rens)
    T  = int(DATA.T)
    nL = len(DATA.lines)
    hrs = np.arange(T)

    # ── Figure: 2×2 grid ─────────────────────────────────────────────────
    fig = plt.figure(figsize=(18, 11))
    fig.suptitle(
        f"Branch-and-Sandwich — {label}   [foil: {foil_label}]",
        fontsize=13, fontweight="bold",
    )
    gs  = gridspec.GridSpec(2, 2, figure=fig, hspace=0.45, wspace=0.28)
    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[0, 1])
    ax3 = fig.add_subplot(gs[1, 0])
    ax4 = fig.add_subplot(gs[1, 1])

    # ── Dispatch panels ───────────────────────────────────────────────────
    def _dispatch_panel(ax, sol, title):
        if sol is None:
            ax.set_title(f"{title} (N/A)"); return
        # Normalise p to a (nG, T) numpy array regardless of how the solver returns it
        p_raw = sol["p"]
        if isinstance(p_raw, dict):
            p_mat = np.array([[float(p_raw[g, t]) for t in range(T)] for g in range(nG)])
        else:
            p_mat = np.asarray(p_raw, dtype=float)
            if p_mat.shape == (T, nG):
                p_mat = p_mat.T
        sol = dict(sol, p=p_mat)
        bottom = np.zeros(T)
        for g in range(nG):
            col = TECH_COLORS[g % len(TECH_COLORS)]
            ax.fill_between(hrs, bottom, bottom + sol["p"][g],
                            color=col, alpha=0.75, label=f"G{g}", step="mid")
            bottom += sol["p"][g]
        if nR > 0 and "curt" in sol:
            avail = np.vstack([r.avail for r in DATA.rens])
            ren_inj = (avail - sol["curt"]).sum(axis=0)
            ax.fill_between(hrs, bottom, bottom + ren_inj,
                            color="#1D9E75", alpha=0.5, label="Renewable", step="mid")
            bottom += ren_inj
        ax.plot(hrs, bottom, color="orange", lw=1.8, label="Total production", zorder=5)
        ax.plot(hrs, DATA.demand.sum(axis=0), "k--", lw=1.5, label="Demand")
        ax.set_title(title, fontsize=10)
        ax.set_xlabel("Hour"); ax.set_ylabel("MW")
        ax.grid(True, alpha=0.3)
        ax.legend(fontsize=7, ncol=4, loc="upper left")

    _dispatch_panel(ax1, sol0,         "Factual dispatch  (b = b₀)")
    _dispatch_panel(ax2, sol_foil_hat, "Counterfactual dispatch  (b = b̂, foil active)")

    # ── Curtailment comparison ────────────────────────────────────────────
    curtF   = sol0["curt"].sum(axis=0)          if nR>0 and "curt" in sol0         else np.zeros(T)
    curtCF  = sol_foil_hat["curt"].sum(axis=0)  if sol_foil_hat is not None and nR>0 and "curt" in sol_foil_hat  else np.zeros(T)
    curtP   = sol_plain_hat["curt"].sum(axis=0) if sol_plain_hat is not None and nR>0 and "curt" in sol_plain_hat else np.zeros(T)

    ax3.bar(hrs - 0.27, curtF,  0.26, color="#D85A30", alpha=0.85, label=f"Factual  ({curtF.sum():.1f} MWh)")
    ax3.bar(hrs,        curtP,  0.26, color="#BA7517", alpha=0.85, label=f"Plain@b̂  ({curtP.sum():.1f} MWh)")
    ax3.bar(hrs + 0.27, curtCF, 0.26, color="#378ADD", alpha=0.85, label=f"Foil@b̂   ({curtCF.sum():.1f} MWh)")
    ax3.set_title("Curtailment per hour (MWh)", fontsize=10)
    ax3.set_xlabel("Hour"); ax3.set_ylabel("MWh")
    ax3.legend(fontsize=8); ax3.grid(True, alpha=0.3, axis="y")

    # ── Line-limit changes (per-unit) ─────────────────────────────────────
    b_hat_pu = b_hat / np.maximum(b0, 1e-12)
    changed  = np.where(np.abs(b_hat_pu - 1.0) > 1e-4)[0]
    x_all    = np.arange(nL)

    ax4.bar(x_all, b_hat_pu, color="#cccccc", alpha=0.6, label="Unchanged")
    if len(changed):
        ax4.bar(changed, b_hat_pu[changed], color="#378ADD", alpha=0.9, label="Changed")
    ax4.axhline(1.0, color="k", lw=1.0, ls="--", label="Original (1.0 p.u.)")
    ax4.set_title("Line limits — counterfactual vs original  (p.u.)", fontsize=10)
    ax4.set_xlabel("Line index ℓ"); ax4.set_ylabel("b̂ / b₀  (p.u.)")
    ax4.legend(fontsize=8); ax4.grid(True, alpha=0.3, axis="y")
    ax4.text(0.98, 0.97, f"{len(changed)} line(s) changed",
             transform=ax4.transAxes, ha="right", va="top", fontsize=8)

    plt.tight_layout(rect=[0, 0, 1, 0.97])
    plt.show()

    # ── Numeric summary ───────────────────────────────────────────────────
    F_best = float(res_bs.get("F_opt", np.nan))
    LB     = res_bs.get("global_LB", res_bs.get("LB", np.nan))
    LB     = float(LB) if LB is not None else np.nan
    gap_pct = (100.0 * max(0.0, F_best - LB) / abs(F_best)
               if np.isfinite(F_best) and np.isfinite(LB) and abs(F_best) > 1e-12
               else np.nan)

    print(f"\n{label} — B&S summary:")
    print(f"  Nodes processed : {res_bs.get('nodes')}")
    print(f"  F_opt (incumbent): {F_best:.6f}")
    print(f"  Global LB        : {LB:.6f}")
    print(f"  Gap              : {gap_pct:.3f}%")
    print(f"  Certified        : {res_bs.get('certified')}")

    if len(changed):
        delta_abs = b_hat - b0
        delta_pu  = delta_abs / np.maximum(b0, 1e-12)
        util_arr  = np.max(np.abs(sol0["f"]), axis=1) / np.maximum(b0, 1e-9)
        print(f"  {'ell':>4}  {'fr->to':>6}  {'b0(MW)':>9}  {'b_hat(MW)':>10}  {'Δ(MW)':>8}  "
              f"{'b_hat(pu)':>10}  {'Δ(pu)':>8}  {'util':>6}")
        rows = sorted(
            [(ell, int(DATA.lines[ell].fr), int(DATA.lines[ell].to),
              b0[ell], b_hat[ell], delta_abs[ell], b_hat_pu[ell], delta_pu[ell], util_arr[ell])
             for ell in changed],
            key=lambda r: -abs(r[7]),
        )
        for ell, fr, to, b0v, bhv, dv, bhpu, dpu, uti in rows:
            print(f"  {ell:>4}  {fr:>2}->{to:<3}  {b0v:>9.3f}  {bhv:>10.3f}  {dv:>8.3f}  "
                  f"{bhpu:>10.3f}  {dpu:>+8.3f}  {uti:>6.3f}")
    else:
        print("  (No line limits changed.)")

print("plot_bs_results defined.")
# Out:
# plot_bs_results defined.

# %% [markdown]
# ---
# ## Section 1 · Dataset loading
#
# Load all seven IEEE benchmark grids from JSON files in `DATA_DIR`.
# `quick_setup` returns `DATA, idx, cvec, b0, u_init, p_init, on_t, off_t`.

# %%
import os as _os
DATA_6, idx_6, cvec_6, b0_6, \
    u_init_6, p_init_6, on_t_6, off_t_6 = quick_setup(
    _os.path.join(DATA_DIR, "6bus_wood_wollenberg.json"),
    carbon_price=None,
    voll=20_000.0,
    slack_bus=None,
)
print(f"6-bus (Wood & Wollenberg)  |  buses={DATA_6.nB}  lines={len(DATA_6.lines)}  "
      f"gens={len(DATA_6.gens)}  T={int(DATA_6.T)}h")
# Out:
# Loaded: 6bus_wood_wollenberg.json
#   Buses: 6  |  Lines: 9  |  T: 24h
#   Generators: 3  |  Renewables: 2
#   System peak demand: 286.4 MW
#   Total renewable capacity: 280.0 MW
#   Carbon price: 50.0 $/tCO2
# 6-bus (Wood & Wollenberg)  |  buses=6  lines=9  gens=3  T=24h

# %%
import os as _os
DATA_14, idx_14, cvec_14, b0_14, \
    u_init_14, p_init_14, on_t_14, off_t_14 = quick_setup(
    _os.path.join(DATA_DIR, "ieee14_enhanced.json"),
    carbon_price=None,
    voll=20_000.0,
    slack_bus=None,
)
print(f"IEEE 14-bus  |  buses={DATA_14.nB}  lines={len(DATA_14.lines)}  "
      f"gens={len(DATA_14.gens)}  T={int(DATA_14.T)}h")
# Out:
# Loaded: ieee14_enhanced.json
#   Buses: 14  |  Lines: 20  |  T: 24h
#   Generators: 6  |  Renewables: 2
#   System peak demand: 648.4 MW
#   Total renewable capacity: 570.0 MW
#   Carbon price: 50.0 $/tCO2
# IEEE 14-bus  |  buses=14  lines=20  gens=6  T=24h

# %%
import os as _os
DATA_30, idx_30, cvec_30, b0_30, \
    u_init_30, p_init_30, on_t_30, off_t_30 = quick_setup(
    _os.path.join(DATA_DIR, "ieee30_uc.json"),
    carbon_price=None,
    voll=20_000.0,
    slack_bus=None,
    demand_scaling=0.8,
)
print(f"IEEE 30-bus  |  buses={DATA_30.nB}  lines={len(DATA_30.lines)}  "
      f"gens={len(DATA_30.gens)}  T={int(DATA_30.T)}h")
# Out:
# Loaded: ieee30_uc.json
#   Buses: 30  |  Lines: 41  |  T: 24h
#   Generators: 6  |  Renewables: 2
#   System peak demand: 226.7 MW
#   Total renewable capacity: 74.3 MW
#   Carbon price: 50.0 $/tCO2
# IEEE 30-bus  |  buses=30  lines=41  gens=6  T=24h

# %%
import os as _os
DATA_39, idx_39, cvec_39, b0_39, \
    u_init_39, p_init_39, on_t_39, off_t_39 = quick_setup(
    _os.path.join(DATA_DIR, "ieee39_newengland.json"),
    carbon_price=None,
    voll=20_000.0,
    slack_bus=None,
    demand_scaling=0.8,
    ren_scaling=1.2,
)
print(f"IEEE 39-bus  |  buses={DATA_39.nB}  lines={len(DATA_39.lines)}  "
      f"gens={len(DATA_39.gens)}  T={int(DATA_39.T)}h")
# Out:
# Loaded: ieee39_newengland.json
#   Buses: 39  |  Lines: 46  |  T: 24h
#   Generators: 10  |  Renewables: 4
#   System peak demand: 2125.1 MW
#   Total renewable capacity: 2280.0 MW
#   Carbon price: 50.0 $/tCO2
# IEEE 39-bus  |  buses=39  lines=46  gens=10  T=24h

# %%
import os as _os
DATA_57, idx_57, cvec_57, b0_57, \
    u_init_57, p_init_57, on_t_57, off_t_57 = quick_setup(
    _os.path.join(DATA_DIR, "ieee57_uc.json"),
    carbon_price=None,
    voll=20_000.0,
    slack_bus=None,
    ren_scaling= 2.5,
)
print(f"IEEE 57-bus  |  buses={DATA_57.nB}  lines={len(DATA_57.lines)}  "
      f"gens={len(DATA_57.gens)}  T={int(DATA_57.T)}h")
# Out:
# Loaded: ieee57_uc.json
#   Buses: 57  |  Lines: 76  |  T: 24h
#   Generators: 7  |  Renewables: 3
#   System peak demand: 1251.0 MW
#   Total renewable capacity: 690.0 MW
#   Carbon price: 50.0 $/tCO2
# IEEE 57-bus  |  buses=57  lines=76  gens=7  T=24h

# %%
import os as _os
DATA_118, idx_118, cvec_118, b0_118, \
    u_init_118, p_init_118, on_t_118, off_t_118 = quick_setup(
    _os.path.join(DATA_DIR, "ieee118_uc.json"),
    carbon_price=None,
    voll=20_000.0,
    slack_bus=None,
    demand_scaling=0.8,
)
print(f"IEEE 118-bus  |  buses={DATA_118.nB}  lines={len(DATA_118.lines)}  "
      f"gens={len(DATA_118.gens)}  T={int(DATA_118.T)}h")
# Out:
# Loaded: ieee118_uc.json
#   Buses: 118  |  Lines: 120  |  T: 24h
#   Generators: 54  |  Renewables: 4
#   System peak demand: 3393.6 MW
#   Total renewable capacity: 985.5 MW
#   Carbon price: 50.0 $/tCO2
# IEEE 118-bus  |  buses=118  lines=120  gens=54  T=24h

# %%
import os as _os
DATA_300, idx_300, cvec_300, b0_300, \
    u_init_300, p_init_300, on_t_300, off_t_300 = quick_setup(
    _os.path.join(DATA_DIR, "ieee300_uc.json"),
    carbon_price=None,
    voll=20_000.0,
    slack_bus=None,
    ren_scaling= 2.5,
)
print(f"IEEE 300-bus  |  buses={DATA_300.nB}  lines={len(DATA_300.lines)}  "
      f"gens={len(DATA_300.gens)}  T={int(DATA_300.T)}h")
# Out:
# Loaded: ieee300_uc.json
#   Buses: 300  |  Lines: 309  |  T: 24h
#   Generators: 69  |  Renewables: 5
#   System peak demand: 23525.0 MW
#   Total renewable capacity: 7269.3 MW
#   Carbon price: 50.0 $/tCO2
# IEEE 300-bus  |  buses=300  lines=309  gens=69  T=24h

# %% [markdown]
# ---
# ## Section 2 · Factual UC solve and emissions baseline
#
# For each grid: solve the plain UC at b₀, compute the factual emissions,
# build the **20 % emissions-reduction foil**, select the **top-K most
# utilised lines** as free variables, and build per-unit line weights.

# %% [markdown]
# ### 3.1 · 6-bus (Wood & Wollenberg)

# %%
# ── Factual solve — 6-bus (Wood & Wollenberg) ──────────────────────────────────────────
_, solF_6, zF_6 = solve_uc_with_cost_4b(
    data=DATA_6, idx=idx_6, cvec=cvec_6,
    window_size=int(DATA_6.T), per_bus_neutrality=True,
    u_init=u_init_6, p_init=p_init_6,
    on_time_init=on_t_6, off_time_init=off_t_6,
    output_flag=0,
)
assert solF_6 is not None, "Factual solve failed for 6-bus (Wood & Wollenberg)"

# Emissions baseline
e_6        = np.array([float(g.emission_rate) for g in DATA_6.gens], dtype=float)
E_factual_6 = float(np.sum(e_6[:, None] * solF_6["p"]))

# Emissions foil: require >= ALPHA reduction
foil_fn_6 = make_emissions_foil_4b(DATA_6, alpha=ALPHA, E_factual=E_factual_6)

# Top-K free lines by utilisation
b_free_idx_6, util_6 = get_congested_free_lines(solF_6, b0_6, thr=UTIL_THR)
bL_6, bU_6            = build_b_bounds(b0_6, b_free_idx_6)
w_6                        = make_line_weights(DATA_6, b0_6, util=util_6)

# Oracle
oracle_6 = UCWeakWCEOracle(
    data=DATA_6, cvec=cvec_6, idx=idx_6,
    window_size=int(DATA_6.T), per_bus_neutrality=True,
    u_init=u_init_6, p_init=p_init_6, on_t=on_t_6, off_t=off_t_6,
    foil_extra_constr_fn=foil_fn_6,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil is feasible at b0
vF_6, _, solFoil_b0_6 = oracle_6.solve_foil(b0_6)
factual_obj_6 = float(np.dot(cvec_6, zF_6))

print(f"6-bus (Wood & Wollenberg)")
print(f"  Factual obj        : {factual_obj_6:.0f}")
print(f"  Factual emissions  : {E_factual_6:.2f}")
print(f"  Emissions target   : {(1 - ALPHA) * E_factual_6:.2f}  ({ALPHA:.0%} reduction)")
print(f"  Foil feasible@b0   : {solFoil_b0_6 is not None}")
print(f"  Free lines (util>={UTIL_THR:.0%}): {b_free_idx_6}")
print(f"  b0 range           : min={b0_6.min():.1f}  max={b0_6.max():.1f} MW")
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2653481
# Academic license 2653481 - for non-commercial use only - registered to to___@ug.uchile.cl
# 6-bus (Wood & Wollenberg)
#   Factual obj        : 214823
#   Factual emissions  : 2119.90
#   Emissions target   : 1907.91  (10% reduction)
#   Foil feasible@b0   : True
#   Free lines (util>=75%): [0, 1, 2, 5, 7, 8]
#   b0 range           : min=24.0  max=80.0 MW

# %% [markdown]
# ### 3.2 · IEEE 14-bus

# %%
# ── Factual solve — IEEE 14-bus ──────────────────────────────────────────
_, solF_14, zF_14 = solve_uc_with_cost_4b(
    data=DATA_14, idx=idx_14, cvec=cvec_14,
    window_size=int(DATA_14.T), per_bus_neutrality=True,
    u_init=u_init_14, p_init=p_init_14,
    on_time_init=on_t_14, off_time_init=off_t_14,
    output_flag=0,
)
assert solF_14 is not None, "Factual solve failed for IEEE 14-bus"

# Emissions baseline
e_14        = np.array([float(g.emission_rate) for g in DATA_14.gens], dtype=float)
E_factual_14 = float(np.sum(e_14[:, None] * solF_14["p"]))

# Emissions foil: require >= ALPHA reduction
foil_fn_14 = make_emissions_foil_4b(DATA_14, alpha=ALPHA, E_factual=E_factual_14)

# Top-K free lines by utilisation
b_free_idx_14, util_14 = get_congested_free_lines(solF_14, b0_14, thr=UTIL_THR)
bL_14, bU_14            = build_b_bounds(b0_14, b_free_idx_14)
w_14                        = make_line_weights(DATA_14, b0_14, util=util_14)

# Oracle
oracle_14 = UCWeakWCEOracle(
    data=DATA_14, cvec=cvec_14, idx=idx_14,
    window_size=int(DATA_14.T), per_bus_neutrality=True,
    u_init=u_init_14, p_init=p_init_14, on_t=on_t_14, off_t=off_t_14,
    foil_extra_constr_fn=foil_fn_14,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil is feasible at b0
vF_14, _, solFoil_b0_14 = oracle_14.solve_foil(b0_14)
factual_obj_14 = float(np.dot(cvec_14, zF_14))

print(f"IEEE 14-bus")
print(f"  Factual obj        : {factual_obj_14:.0f}")
print(f"  Factual emissions  : {E_factual_14:.2f}")
print(f"  Emissions target   : {(1 - ALPHA) * E_factual_14:.2f}  ({ALPHA:.0%} reduction)")
print(f"  Foil feasible@b0   : {solFoil_b0_14 is not None}")
print(f"  Free lines (util>={UTIL_THR:.0%}): {b_free_idx_14}")
print(f"  b0 range           : min={b0_14.min():.1f}  max={b0_14.max():.1f} MW")
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2653481
# Academic license 2653481 - for non-commercial use only - registered to to___@ug.uchile.cl
# IEEE 14-bus
#   Factual obj        : 895956
#   Factual emissions  : 6498.17
#   Emissions target   : 5848.36  (10% reduction)
#   Foil feasible@b0   : True
#   Free lines (util>=75%): [0, 2, 6, 14, 15, 18]
#   b0 range           : min=39.0  max=200.0 MW

# %% [markdown]
# ### 3.3 · IEEE 30-bus

# %%
# ── Factual solve — IEEE 30-bus ──────────────────────────────────────────
_, solF_30, zF_30 = solve_uc_with_cost_4b(
    data=DATA_30, idx=idx_30, cvec=cvec_30,
    window_size=int(DATA_30.T), per_bus_neutrality=True,
    u_init=u_init_30, p_init=p_init_30,
    on_time_init=on_t_30, off_time_init=off_t_30,
    output_flag=0,
)
assert solF_30 is not None, "Factual solve failed for IEEE 30-bus"

# Emissions baseline
e_30        = np.array([float(g.emission_rate) for g in DATA_30.gens], dtype=float)
E_factual_30 = float(np.sum(e_30[:, None] * solF_30["p"]))

# Emissions foil: require >= ALPHA reduction
foil_fn_30 = make_emissions_foil_4b(DATA_30, alpha=ALPHA, E_factual=E_factual_30)

# Top-K free lines by utilisation
b_free_idx_30, util_30 = get_congested_free_lines(solF_30, b0_30, thr=UTIL_THR)
bL_30, bU_30            = build_b_bounds(b0_30, b_free_idx_30)
w_30                        = make_line_weights(DATA_30, b0_30, util=util_30)

# Oracle
oracle_30 = UCWeakWCEOracle(
    data=DATA_30, cvec=cvec_30, idx=idx_30,
    window_size=int(DATA_30.T), per_bus_neutrality=True,
    u_init=u_init_30, p_init=p_init_30, on_t=on_t_30, off_t=off_t_30,
    foil_extra_constr_fn=foil_fn_30,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil is feasible at b0
vF_30, _, solFoil_b0_30 = oracle_30.solve_foil(b0_30)
factual_obj_30 = float(np.dot(cvec_30, zF_30))

print(f"IEEE 30-bus")
print(f"  Factual obj        : {factual_obj_30:.0f}")
print(f"  Factual emissions  : {E_factual_30:.2f}")
print(f"  Emissions target   : {(1 - ALPHA) * E_factual_30:.2f}  ({ALPHA:.0%} reduction)")
print(f"  Foil feasible@b0   : {solFoil_b0_30 is not None}")
print(f"  Free lines (util>={UTIL_THR:.0%}): {b_free_idx_30}")
print(f"  b0 range           : min={b0_30.min():.1f}  max={b0_30.max():.1f} MW")
# Out:
# IEEE 30-bus
#   Factual obj        : 363356
#   Factual emissions  : 2122.27
#   Emissions target   : 1910.05  (10% reduction)
#   Foil feasible@b0   : True
#   Free lines (util>=75%): [34]
#   b0 range           : min=32.0  max=130.0 MW

# %% [markdown]
# ### 3.4 · IEEE 39-bus

# %%
# ── Factual solve — IEEE 39-bus ──────────────────────────────────────────
_, solF_39, zF_39 = solve_uc_with_cost_4b(
    data=DATA_39, idx=idx_39, cvec=cvec_39,
    window_size=int(DATA_39.T), per_bus_neutrality=True,
    u_init=u_init_39, p_init=p_init_39,
    on_time_init=on_t_39, off_time_init=off_t_39,
    output_flag=0,
)
assert solF_39 is not None, "Factual solve failed for IEEE 39-bus"

# Emissions baseline
e_39        = np.array([float(g.emission_rate) for g in DATA_39.gens], dtype=float)
E_factual_39 = float(np.sum(e_39[:, None] * solF_39["p"]))

# Emissions foil: require >= ALPHA reduction
foil_fn_39 = make_emissions_foil_4b(DATA_39, alpha=ALPHA, E_factual=E_factual_39)

# Top-K free lines by utilisation
b_free_idx_39, util_39 = get_congested_free_lines(solF_39, b0_39, thr=UTIL_THR)
bL_39, bU_39            = build_b_bounds(b0_39, b_free_idx_39)
w_39                        = make_line_weights(DATA_39, b0_39, util=util_39)

# Oracle
oracle_39 = UCWeakWCEOracle(
    data=DATA_39, cvec=cvec_39, idx=idx_39,
    window_size=int(DATA_39.T), per_bus_neutrality=True,
    u_init=u_init_39, p_init=p_init_39, on_t=on_t_39, off_t=off_t_39,
    foil_extra_constr_fn=foil_fn_39,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil is feasible at b0
vF_39, _, solFoil_b0_39 = oracle_39.solve_foil(b0_39)
factual_obj_39 = float(np.dot(cvec_39, zF_39))

print(f"IEEE 39-bus")
print(f"  Factual obj        : {factual_obj_39:.0f}")
print(f"  Factual emissions  : {E_factual_39:.2f}")
print(f"  Emissions target   : {(1 - ALPHA) * E_factual_39:.2f}  ({ALPHA:.0%} reduction)")
print(f"  Foil feasible@b0   : {solFoil_b0_39 is not None}")
print(f"  Free lines (util>={UTIL_THR:.0%}): {b_free_idx_39}")
print(f"  b0 range           : min={b0_39.min():.1f}  max={b0_39.max():.1f} MW")
# Out:
# IEEE 39-bus
#   Factual obj        : 78680
#   Factual emissions  : 94.53
#   Emissions target   : 85.08  (10% reduction)
#   Foil feasible@b0   : True
#   Free lines (util>=75%): [4, 6, 9, 13, 19, 42, 45]
#   b0 range           : min=192.0  max=1200.0 MW

# %% [markdown]
# ### 3.5 · IEEE 57-bus

# %%
# ── Factual solve — IEEE 57-bus ──────────────────────────────────────────
_, solF_57, zF_57 = solve_uc_with_cost_4b(
    data=DATA_57, idx=idx_57, cvec=cvec_57,
    window_size=int(DATA_57.T), per_bus_neutrality=True,
    u_init=u_init_57, p_init=p_init_57,
    on_time_init=on_t_57, off_time_init=off_t_57,
    output_flag=0,
)
assert solF_57 is not None, "Factual solve failed for IEEE 57-bus"

# Emissions baseline
e_57        = np.array([float(g.emission_rate) for g in DATA_57.gens], dtype=float)
E_factual_57 = float(np.sum(e_57[:, None] * solF_57["p"]))

# Emissions foil: require >= ALPHA reduction
foil_fn_57 = make_emissions_foil_4b(DATA_57, alpha=ALPHA, E_factual=E_factual_57)

# Top-K free lines by utilisation
b_free_idx_57, util_57 = get_congested_free_lines(solF_57, b0_57, thr=UTIL_THR)
bL_57, bU_57            = build_b_bounds(b0_57, b_free_idx_57)
w_57                        = make_line_weights(DATA_57, b0_57, util=util_57)

# Oracle
oracle_57 = UCWeakWCEOracle(
    data=DATA_57, cvec=cvec_57, idx=idx_57,
    window_size=int(DATA_57.T), per_bus_neutrality=True,
    u_init=u_init_57, p_init=p_init_57, on_t=on_t_57, off_t=off_t_57,
    foil_extra_constr_fn=foil_fn_57,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil is feasible at b0
vF_57, _, solFoil_b0_57 = oracle_57.solve_foil(b0_57)
factual_obj_57 = float(np.dot(cvec_57, zF_57))

print(f"IEEE 57-bus")
print(f"  Factual obj        : {factual_obj_57:.0f}")
print(f"  Factual emissions  : {E_factual_57:.2f}")
print(f"  Emissions target   : {(1 - ALPHA) * E_factual_57:.2f}  ({ALPHA:.0%} reduction)")
print(f"  Foil feasible@b0   : {solFoil_b0_57 is not None}")
print(f"  Free lines (util>={UTIL_THR:.0%}): {b_free_idx_57}")
print(f"  b0 range           : min={b0_57.min():.1f}  max={b0_57.max():.1f} MW")
# Out:
# IEEE 57-bus
#   Factual obj        : 95759655
#   Factual emissions  : 10261.46
#   Emissions target   : 9235.31  (10% reduction)
#   Foil feasible@b0   : True
#   Free lines (util>=75%): [2, 3, 15, 20, 42, 43, 44, 62, 63, 70, 72, 75]
#   b0 range           : min=130.0  max=250.0 MW

# %% [markdown]
# ### 3.6 · IEEE 118-bus

# %%
# ── Factual solve — IEEE 118-bus ──────────────────────────────────────────
_, solF_118, zF_118 = solve_uc_with_cost_4b(
    data=DATA_118, idx=idx_118, cvec=cvec_118,
    window_size=int(DATA_118.T), per_bus_neutrality=True,
    u_init=u_init_118, p_init=p_init_118,
    on_time_init=on_t_118, off_time_init=off_t_118,
    output_flag=0,
)
assert solF_118 is not None, "Factual solve failed for IEEE 118-bus"

# Emissions baseline
e_118        = np.array([float(g.emission_rate) for g in DATA_118.gens], dtype=float)
E_factual_118 = float(np.sum(e_118[:, None] * solF_118["p"]))

# Emissions foil: require >= ALPHA reduction
foil_fn_118 = make_emissions_foil_4b(DATA_118, alpha=ALPHA, E_factual=E_factual_118)

# Top-K free lines by utilisation
b_free_idx_118, util_118 = get_congested_free_lines(solF_118, b0_118, thr=UTIL_THR)
bL_118, bU_118            = build_b_bounds(b0_118, b_free_idx_118)
w_118                        = make_line_weights(DATA_118, b0_118, util=util_118)

# Oracle
oracle_118 = UCWeakWCEOracle(
    data=DATA_118, cvec=cvec_118, idx=idx_118,
    window_size=int(DATA_118.T), per_bus_neutrality=True,
    u_init=u_init_118, p_init=p_init_118, on_t=on_t_118, off_t=off_t_118,
    foil_extra_constr_fn=foil_fn_118,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil is feasible at b0
vF_118, _, solFoil_b0_118 = oracle_118.solve_foil(b0_118)
factual_obj_118 = float(np.dot(cvec_118, zF_118))

print(f"IEEE 118-bus")
print(f"  Factual obj        : {factual_obj_118:.0f}")
print(f"  Factual emissions  : {E_factual_118:.2f}")
print(f"  Emissions target   : {(1 - ALPHA) * E_factual_118:.2f}  ({ALPHA:.0%} reduction)")
print(f"  Foil feasible@b0   : {solFoil_b0_118 is not None}")
print(f"  Free lines (util>={UTIL_THR:.0%}): {b_free_idx_118}")
print(f"  b0 range           : min={b0_118.min():.1f}  max={b0_118.max():.1f} MW")
# Out:
# IEEE 118-bus
#   Factual obj        : 69706316
#   Factual emissions  : 42228.70
#   Emissions target   : 38005.83  (10% reduction)
#   Foil feasible@b0   : True
#   Free lines (util>=75%): [14, 36, 37, 38, 39, 46, 47, 48, 49, 50, 51, 59, 60, 61, 62, 63, 84, 85, 86, 87, 88, 94, 95, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 109, 110]
#   b0 range           : min=175.0  max=500.0 MW

# %% [markdown]
# ### 3.7 · IEEE 300-bus

# %%
# ── Factual solve — IEEE 300-bus ──────────────────────────────────────────
_, solF_300, zF_300 = solve_uc_with_cost_4b(
    data=DATA_300, idx=idx_300, cvec=cvec_300,
    window_size=int(DATA_300.T), per_bus_neutrality=True,
    u_init=u_init_300, p_init=p_init_300,
    on_time_init=on_t_300, off_time_init=off_t_300,
    output_flag=0,
)
assert solF_300 is not None, "Factual solve failed for IEEE 300-bus"

# Emissions baseline
e_300        = np.array([float(g.emission_rate) for g in DATA_300.gens], dtype=float)
E_factual_300 = float(np.sum(e_300[:, None] * solF_300["p"]))

# Emissions foil: require >= ALPHA reduction
foil_fn_300 = make_emissions_foil_4b(DATA_300, alpha=ALPHA, E_factual=E_factual_300)

# Top-K free lines by utilisation
b_free_idx_300, util_300 = get_congested_free_lines(solF_300, b0_300, thr=UTIL_THR)
bL_300, bU_300            = build_b_bounds(b0_300, b_free_idx_300)
w_300                        = make_line_weights(DATA_300, b0_300, util=util_300)

# Oracle
oracle_300 = UCWeakWCEOracle(
    data=DATA_300, cvec=cvec_300, idx=idx_300,
    window_size=int(DATA_300.T), per_bus_neutrality=True,
    u_init=u_init_300, p_init=p_init_300, on_t=on_t_300, off_t=off_t_300,
    foil_extra_constr_fn=foil_fn_300,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil is feasible at b0
vF_300, _, solFoil_b0_300 = oracle_300.solve_foil(b0_300)
factual_obj_300 = float(np.dot(cvec_300, zF_300))

print(f"IEEE 300-bus")
print(f"  Factual obj        : {factual_obj_300:.0f}")
print(f"  Factual emissions  : {E_factual_300:.2f}")
print(f"  Emissions target   : {(1 - ALPHA) * E_factual_300:.2f}  ({ALPHA:.0%} reduction)")
print(f"  Foil feasible@b0   : {solFoil_b0_300 is not None}")
print(f"  Free lines (util>={UTIL_THR:.0%}): {b_free_idx_300}")
print(f"  b0 range           : min={b0_300.min():.1f}  max={b0_300.max():.1f} MW")
# Out:
# IEEE 300-bus
#   Factual obj        : 5207723798
#   Factual emissions  : 117197.83
#   Emissions target   : 105478.05  (10% reduction)
#   Foil feasible@b0   : True
#   Free lines (util>=75%): [1, 2, 7, 8, 11, 15, 18, 19, 20, 21, 22, 24, 26, 28, 30, 32, 33, 35, 36, 37, 38, 39, 42, 46, 49, 50, 52, 53, 55, 57, 58, 59, 61, 62, 69, 70, 74, 78, 79, 80, 85, 87, 89, 91, 94, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 111, 112, 113, 114, 115, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308]
#   b0 range           : min=200.0  max=400.0 MW

# %% [markdown]
# ---
# ## Section 3 · Branch-and-Sandwich — minimum line-limit change
#
# For each grid, B&S finds the **minimum change to line flow limits** (b vector)
# such that the 20 % emissions-reduction foil is weakly satisfied at the
# counterfactual optimum.
#
# The 6-bus grid is run **twice**: once with the emissions foil and once with
# a commitment-flip foil, to allow direct comparison of the two foil types.

# %% [markdown]
# ### 3.1 · 6-bus (Wood & Wollenberg)

# %%
# ── Branch-and-Sandwich — 6-bus (Wood & Wollenberg) ──────────────────────────────────────
assert solFoil_b0_6 is not None, \
    "Foil is infeasible at b0 for 6-bus (Wood & Wollenberg) — check emissions data."

def _make_emission_viol_fn_6():
    E_f  = E_factual_6
    tgt  = (1 - ALPHA) * E_f
    e_g  = e_6
    def viol_fn(m, var, idx):
        s = m.addVar(lb=0.0, name="emis_viol")
        total_emis = gp.quicksum(
            e_g[g] * var["p"][g, t]
            for g in range(len(e_g))
            for t in range(int(DATA_6.T))
        )
        m.addConstr(s >= (total_emis - tgt) / max(E_f, 1.0), name="emis_viol_constr")
        m.update()
        return s
    return viol_fn

viol_fn_6 = _make_emission_viol_fn_6()

bs_6 = UCBranchAndSandwichWCE_4b(
    oracle=oracle_6,
    data=DATA_6, idx=idx_6, cvec=cvec_6,
    foil_extra_constr_fn=foil_fn_6,
    b0=b0_6,
    b_bounds=(bL_6, bU_6),
    b_free_idx=b_free_idx_6,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_6,
    foil_violation_expr_fn=viol_fn_6,
    lagrange_penalty=200.0,
)

res_bs_6 = bs_6.run(
    window_size=int(DATA_6.T),
    per_bus_neutrality=True,
    u_init=u_init_6, p_init=p_init_6,
    on_t=on_t_6, off_t=off_t_6,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\n6-bus (Wood & Wollenberg)  certified={res_bs_6['certified']}  "
      f"gap={res_bs_6.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_6.get('nodes')}")
# Out:
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [INC] b_max: F=1410.6743 v=85824.831 v_D=85824.831
#   [INNER_UB] tightened by incumbent: 85824.8306
# [BS] node=0000 olb=0.0000 inner=[980.52,214823.10] bestF=1410.6743 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [INC] node=0000: F=705.3372 v=85824.831 v_D=85824.831
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [INC] node=0000: F=4.2000 v=125322.607 v_D=125322.607
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=275.8305 > bestF=4.2000)
# [BS] node=0001 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [INNER_UB] tightened by incumbent: 85824.8306
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=230.5773 > bestF=4.2000)
# [BS] node=0003 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=159.4969 > bestF=4.2000)
# [BS] node=0005 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=137.9152 > bestF=4.2000)
# [BS] node=0007 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=115.2886 > bestF=4.2000)
# [BS] node=0009 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=79.7485 > bestF=4.2000)
# [BS] node=0011 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=68.9576 > bestF=4.2000)
# [BS] node=0013 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=57.6443 > bestF=4.2000)
# [BS] node=0015 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=39.8742 > bestF=4.2000)
# [BS] node=0017 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=34.4788 > bestF=4.2000)
# [BS] node=0019 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=28.8222 > bestF=4.2000)
# [BS] node=0021 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=19.9371 > bestF=4.2000)
# [BS] node=0023 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=18.7909 > bestF=4.2000)
# [BS] node=0025 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=17.2394 > bestF=4.2000)
# [BS] node=0027 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=14.4111 > bestF=4.2000)
# [BS] node=0029 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=12.2416 > bestF=4.2000)
# [BS] node=0031 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=9.9686 > bestF=4.2000)
# [BS] node=0033 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214843.442359 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=9.3955 > bestF=4.2000)
# [BS] node=0035 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214843.442359 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=8.6197 > bestF=4.2000)
# [BS] node=0037 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214843.442359 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=8.4000 > bestF=4.2000)
# [BS] node=0039 olb=0.0000 inner=[980.52,214823.10] bestF=4.2000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214843.442359 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [INC] node=0039: F=2.1000 v=171055.005 v_D=171055.005
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=7.2055 > bestF=2.1000)
# [BS] node=0041 olb=0.0000 inner=[980.52,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214843.442359 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=6.1208 > bestF=2.1000)
# [BS] node=0043 olb=0.0000 inner=[980.52,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214843.442359 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=4.9843 > bestF=2.1000)
# [BS] node=0045 olb=0.0000 inner=[980.52,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=4.6977 > bestF=2.1000)
# [BS] node=0047 olb=0.0000 inner=[980.52,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=4.3099 > bestF=2.1000)
# [BS] node=0049 olb=0.0000 inner=[980.52,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=4.2000 > bestF=2.1000)
# [BS] node=0051 olb=0.0000 inner=[1962.37,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=3.6028 > bestF=2.1000)
# [BS] node=0053 olb=0.0000 inner=[1962.37,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=3.0604 > bestF=2.1000)
# [BS] node=0055 olb=0.0000 inner=[1962.37,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=2.4921 > bestF=2.1000)
# [BS] node=0057 olb=0.0000 inner=[1962.37,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=2.3489 > bestF=2.1000)
# [BS] node=0059 olb=0.0000 inner=[1962.37,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=2.1549 > bestF=2.1000)
# [BS] node=0061 olb=0.0000 inner=[1962.37,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
# [BS] node=0063 olb=0.0000 inner=[3530.69,214823.10] bestF=2.1000 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192327.701348 > v=192324.107521 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=204324.421995 > v=203554.054109 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [INC] node=0063: F=1.5750 v=181653.326 v_D=181653.326
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [weak_ok] FAIL: v_D=216031.736057 > v=214610.409021 + eps
#   [LAG_OLB] DISCARDED (lag=1.8014 > bestF=1.5750)
# [BS] node=0065 olb=0.0000 inner=[3530.69,214823.10] bestF=1.5750 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=192327.701348 > v=192324.107521 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
# ...
#   [weak_ok] FAIL: v_D=216232.274741 > v=214793.887501 + eps
#   [weak_ok] FAIL: v_D=216200.350626 > v=214764.679230 + eps
#   [weak_ok] FAIL: v_D=216168.426510 > v=214735.470960 + eps
#   [weak_ok] FAIL: v_D=216136.502395 > v=214706.262690 + eps
#   [LAG_OLB] DISCARDED (lag=1.1731 > bestF=1.0828)
# [BS] node=0607 olb=1.0775 inner=[5347.67,214823.10] bestF=1.0828 gLB=1.0777 gap=0.5%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=214726.604526 > v=213342.546978 + eps
#   [weak_ok] FAIL: v_D=213189.010197 > v=211865.975341 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=215511.363749 > v=214097.425510 + eps
#   [weak_ok] FAIL: v_D=214758.528641 > v=213371.755249 + eps
#   [weak_ok] FAIL: v_D=214005.693534 > v=212648.011285 + eps
#   [weak_ok] FAIL: v_D=213252.858427 > v=211924.391882 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216248.236798 > v=214808.491636 + eps
#   [weak_ok] FAIL: v_D=216232.274741 > v=214793.887501 + eps
#   [weak_ok] FAIL: v_D=216216.312683 > v=214779.283365 + eps
#   [weak_ok] FAIL: v_D=216200.350626 > v=214764.679230 + eps
#   [LAG_OLB] DISCARDED (lag=1.1431 > bestF=1.0828)
# [BS] node=0609 olb=1.0775 inner=[5408.33,214823.10] bestF=1.0828 gLB=1.0777 gap=0.5%
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=215479.439634 > v=214068.217239 + eps
#   [weak_ok] FAIL: v_D=214694.680411 > v=213313.338708 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=215887.781302 > v=214460.260640 + eps
#   [weak_ok] FAIL: v_D=215511.363749 > v=214097.425510 + eps
#   [weak_ok] FAIL: v_D=215134.946195 > v=213734.590379 + eps
#   [weak_ok] FAIL: v_D=214758.528641 > v=213371.755249 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216264.198856 > v=214823.095771 + eps
#   [weak_ok] FAIL: v_D=216248.236798 > v=214808.491636 + eps
#   [weak_ok] FAIL: v_D=216232.274741 > v=214793.887501 + eps
#   [weak_ok] FAIL: v_D=216216.312683 > v=214779.283365 + eps
#   [weak_ok] FAIL: v_D=216200.350626 > v=214764.679230 + eps
# [BS] node=0514 olb=1.0777 inner=[5226.35,210496.99] bestF=1.0828 gLB=1.0800 gap=0.3%
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=210979.980336 > v=209758.233872 + eps
#   [weak_ok] FAIL: v_D=210203.779199 > v=209031.018999 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211384.042962 > v=210142.216053 + eps
#   [weak_ok] FAIL: v_D=211011.904451 > v=209787.442142 + eps
#   [weak_ok] FAIL: v_D=210639.765941 > v=209436.085050 + eps
#   [weak_ok] FAIL: v_D=210267.627430 > v=209089.435540 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211756.181473 > v=210496.989963 + eps
#   [weak_ok] FAIL: v_D=211740.219415 > v=210482.385828 + eps
#   [weak_ok] FAIL: v_D=211724.257358 > v=210467.781693 + eps
#   [weak_ok] FAIL: v_D=211708.295300 > v=210453.177558 + eps
#   [weak_ok] FAIL: v_D=211692.333243 > v=210438.573423 + eps
# [BS] node=0516 olb=1.0800 inner=[4487.71,193850.93] bestF=1.0828 gLB=1.0811 gap=0.2%
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193180.505572 > v=193135.443646 + eps
#   [weak_ok] FAIL: v_D=192427.131098 > v=192419.961190 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193947.682359 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193946.956206 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193946.923455 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193946.923455 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193580.852967 > v=193507.789009 + eps
#   [weak_ok] FAIL: v_D=193213.297421 > v=193164.651916 + eps
#   [weak_ok] FAIL: v_D=192845.741875 > v=192821.514823 + eps
#   [weak_ok] FAIL: v_D=192487.727027 > v=192478.377730 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193948.408513 > v=193850.926102 + eps
#   [weak_ok] FAIL: v_D=193932.446456 > v=193836.321967 + eps
#   [weak_ok] FAIL: v_D=193916.484398 > v=193821.717832 + eps
#   [weak_ok] FAIL: v_D=193900.522340 > v=193807.113697 + eps
#   [weak_ok] FAIL: v_D=193884.560283 > v=193792.509562 + eps
# [BS] node=0354 olb=1.0811 inner=[4466.26,198033.52] bestF=1.0828 gLB=1.0828 gap=0.0%
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=195353.330160 > v=195165.158342 + eps
#   [weak_ok] FAIL: v_D=192327.701348 > v=192324.107521 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=196925.628336 > v=196657.756933 + eps
#   [weak_ok] FAIL: v_D=195482.478928 > v=195281.991424 + eps
#   [weak_ok] FAIL: v_D=194012.256744 > v=193909.342643 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051135 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198297.203000 > v=197975.105901 + eps
#   [weak_ok] FAIL: v_D=198233.354721 > v=197916.689360 + eps
#   [weak_ok] FAIL: v_D=198169.506539 > v=197858.272820 + eps
#   [weak_ok] FAIL: v_D=198128.588431 > v=197820.835692 + eps
#   [LAG_OLB] DISCARDED (lag=1.2724 > bestF=1.0828)
# [BS] node=0611 olb=1.0811 inner=[4487.71,198033.52] bestF=1.0828 gLB=1.0828 gap=0.0%
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=195417.178390 > v=195223.574883 + eps
#   [weak_ok] FAIL: v_D=192427.131098 > v=192419.961190 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=196925.628336 > v=196657.756933 + eps
#   [weak_ok] FAIL: v_D=195482.478928 > v=195281.991424 + eps
#   [weak_ok] FAIL: v_D=194012.256744 > v=193909.342643 + eps
#   [weak_ok] FAIL: v_D=192548.322955 > v=192536.794271 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051135 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198329.127019 > v=198004.314171 + eps
#   [weak_ok] FAIL: v_D=198297.203000 > v=197975.105901 + eps
#   [weak_ok] FAIL: v_D=198265.278885 > v=197945.897630 + eps
#   [weak_ok] FAIL: v_D=198233.354721 > v=197916.689360 + eps
#   [LAG_OLB] DISCARDED (lag=1.2124 > bestF=1.0828)
# [BS] node=0613 olb=1.0811 inner=[4609.03,198033.52] bestF=1.0828 gLB=1.0828 gap=0.0%
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=196861.780105 > v=196599.340392 + eps
#   [weak_ok] FAIL: v_D=195352.062761 > v=195165.158342 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=197643.339783 > v=197345.639687 + eps
#   [weak_ok] FAIL: v_D=196925.628336 > v=196657.756933 + eps
#   [weak_ok] FAIL: v_D=196207.916888 > v=195969.874178 + eps
#   [weak_ok] FAIL: v_D=195482.478928 > v=195281.991424 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051135 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198329.127019 > v=198004.314171 + eps
#   [weak_ok] FAIL: v_D=198297.203000 > v=197975.105901 + eps
#   [weak_ok] FAIL: v_D=198265.278885 > v=197945.897630 + eps
#   [weak_ok] FAIL: v_D=198233.354721 > v=197916.689360 + eps
#   [LAG_OLB] DISCARDED (lag=1.1767 > bestF=1.0828)
# [BS] node=0615 olb=1.0811 inner=[4619.75,198033.52] bestF=1.0828 gLB=1.0828 gap=0.0%
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=196893.704220 > v=196628.548662 + eps
#   [weak_ok] FAIL: v_D=195415.910991 > v=195223.574883 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=197643.339783 > v=197345.639687 + eps
#   [weak_ok] FAIL: v_D=196925.628336 > v=196657.756933 + eps
#   [weak_ok] FAIL: v_D=196207.916888 > v=195969.874178 + eps
#   [weak_ok] FAIL: v_D=195482.478928 > v=195281.991424 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051135 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198345.089172 > v=198018.918306 + eps
#   [weak_ok] FAIL: v_D=198329.127019 > v=198004.314171 + eps
#   [weak_ok] FAIL: v_D=198313.165057 > v=197989.710036 + eps
#   [weak_ok] FAIL: v_D=198297.203000 > v=197975.105901 + eps
#   [LAG_OLB] DISCARDED (lag=1.1467 > bestF=1.0828)
# [BS] node=0617 olb=1.0811 inner=[4680.41,198033.52] bestF=1.0828 gLB=1.0828 gap=0.0%
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=197611.415668 > v=197316.431417 + eps
#   [weak_ok] FAIL: v_D=196861.780105 > v=196599.340392 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198002.195506 > v=197689.581064 + eps
#   [weak_ok] FAIL: v_D=197643.339783 > v=197345.639687 + eps
#   [weak_ok] FAIL: v_D=197284.484059 > v=197001.698310 + eps
#   [weak_ok] FAIL: v_D=196925.628336 > v=196657.756933 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051135 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198361.051230 > v=198033.522441 + eps
#   [weak_ok] FAIL: v_D=198345.089172 > v=198018.918306 + eps
#   [weak_ok] FAIL: v_D=198329.127019 > v=198004.314171 + eps
#   [weak_ok] FAIL: v_D=198313.165057 > v=197989.710036 + eps
#   [weak_ok] FAIL: v_D=198297.203000 > v=197975.105901 + eps
# [BS] CERTIFIED: gLB=1.082812 >= bestF=1.082812
#
# 6-bus (Wood & Wollenberg)  certified=True  gap=0.0000  nodes=513

# %%
# ── Plot — 6-bus (Wood & Wollenberg) ──────────────────────────────────────────────────────
assert res_bs_6.get("success") and res_bs_6.get("b_hat") is not None, \
    "No incumbent for 6-bus (Wood & Wollenberg)."

b_hat_6 = np.array(res_bs_6["b_hat"], dtype=float)

_,_ , sol_plain_hat_6 = oracle_6.solve_plain(b_hat_6)
_, _,  sol_foil_hat_6 = oracle_6.solve_foil(b_hat_6)

plot_bs_results(
    DATA_6, b0_6, b_hat_6,
    sol0=solF_6,
    sol_plain_hat=sol_plain_hat_6,
    sol_foil_hat=sol_foil_hat_6,
    res_bs=res_bs_6,
    label="6-bus (Wood & Wollenberg)",
    foil_label=f"emissions −{ALPHA:.0%}",
)
# Out:
# 6-bus (Wood & Wollenberg) — B&S summary:
#   Nodes processed : 513
#   F_opt (incumbent): 1.082812
#   Global LB        : 1.082812
#   Gap              : 0.000%
#   Certified        : True
#    ell  fr->to     b0(MW)   b_hat(MW)     Δ(MW)   b_hat(pu)     Δ(pu)    util
#      5   2->4       42.000      52.828    10.828       1.258    +0.258   1.000

# %% [markdown]
# ### 3.2 · IEEE 14-bus

# %%
foil_fn_14_base = make_emissions_foil_4b(DATA_14, alpha=ALPHA, E_factual=E_factual_14)

def foil_fn_14(m, var):
    foil_fn_14_base(m, var)
    m.addConstr(
        gp.quicksum(var["shed"][b, t]
                    for b in range(DATA_14.nB)
                    for t in range(int(DATA_14.T))) == 0,
        name="foil_no_shed"
    )

# Patch the oracle directly
oracle_14.foil_extra_constr_fn = foil_fn_14
oracle_14.cache_foil.clear()

# Verify
vF2, _, solFoil2 = oracle_14.solve_foil(b0_14)
print(f"Foil obj: {vF2}")
print(f"Shed:     {solFoil2['shed'].sum() if solFoil2 else 'N/A'}")
# Out:
# Foil obj: None
# Shed:     N/A

# %%
# ── Branch-and-Sandwich — IEEE 14-bus ──────────────────────────────────────
assert solFoil_b0_14 is not None, \
    "Foil is infeasible at b0 for IEEE 14-bus — check emissions data."

def _make_emission_viol_fn_14(shed_weight: float = 1.0):
    """
    Returns a violation function for the Branch-and-Sandwich oracle.

    The slack variable s bounds two normalised quantities:
      - emission excess:  (total_emissions - target) / E_factual
      - load shedding:    shed_weight * total_shed / total_demand_MWh

    Both terms are normalised to [0,1] scale so shed_weight=1.0 means
    one MWh of shedding is penalised equally to emitting E_factual tCO2
    above target. Increase shed_weight to make shedding more costly.
    """
    E_f   = E_factual_14
    tgt   = (1 - ALPHA) * E_f
    e_g   = e_14
    nB    = DATA_14.nB
    T     = int(DATA_14.T)

    # Normaliser for shedding: total demand energy over horizon (MWh)
    total_demand_MWh = float(np.sum(DATA_14.demand))

    def viol_fn(m, var, idx):
        s = m.addVar(lb=0.0, name="emis_viol")

        total_emis = gp.quicksum(
            e_g[g] * var["p"][g, t]
            for g in range(len(e_g))
            for t in range(T)
        )
        total_shed = gp.quicksum(
            var["shed"][b, t]
            for b in range(nB)
            for t in range(T)
        )

        # s >= normalised_emission_excess + normalised_shedding_penalty
        m.addConstr(
            s >= (total_emis - tgt) / max(E_f, 1.0)
               + shed_weight * total_shed / max(total_demand_MWh, 1.0),
            name="emis_viol_constr",
        )
        m.update()
        return s

    return viol_fn

viol_fn_14 = _make_emission_viol_fn_14(shed_weight=1.0)

bs_14 = UCBranchAndSandwichWCE_4b(
    oracle=oracle_14,
    data=DATA_14, idx=idx_14, cvec=cvec_14,
    foil_extra_constr_fn=foil_fn_14,
    b0=b0_14,
    b_bounds=(bL_14, bU_14),
    b_free_idx=b_free_idx_14,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_14,
    foil_violation_expr_fn=viol_fn_14,
    lagrange_penalty=200.0,
    checkpoint_path="bs_14_checkpoint.json",  # <-- add this
)

res_bs_14 = bs_14.run(
    window_size=int(DATA_14.T),
    per_bus_neutrality=True,
    u_init=u_init_14, p_init=p_init_14,
    on_t=on_t_14, off_t=off_t_14,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\nIEEE 14-bus  certified={res_bs_14['certified']}  "
      f"gap={res_bs_14.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_14.get('nodes')}")
# Out:
# [CKPT] Resumed from bs_14_checkpoint.json  bestF=5.1146  nodes_prev=166  gLB=4.8714
# [BS] node=0000 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=214.0360 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=1  bestF=5.1146  gLB=4.5732
# [BS] node=0001 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=163.5064 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=2  bestF=5.1146  gLB=4.5732
# [BS] node=0003 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=107.0180 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=3  bestF=5.1146  gLB=4.5732
# [BS] node=0005 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=81.7532 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=4  bestF=5.1146  gLB=4.5732
# [BS] node=0007 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=53.5090 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=5  bestF=5.1146  gLB=4.5732
# [BS] node=0009 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=45.7649 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=6  bestF=5.1146  gLB=4.5732
# [BS] node=0011 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=40.8766 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=7  bestF=5.1146  gLB=4.5732
# [BS] node=0013 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=26.7545 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=8  bestF=5.1146  gLB=4.5732
# [BS] node=0015 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=22.8825 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=9  bestF=5.1146  gLB=4.5732
# [BS] node=0017 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=20.4383 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=10  bestF=5.1146  gLB=4.5732
# [BS] node=0019 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=19.4491 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=11  bestF=5.1146  gLB=4.5732
# [BS] node=0021 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=13.3773 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=12  bestF=5.1146  gLB=4.5732
# [BS] node=0023 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=11.4412 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=13  bestF=5.1146  gLB=4.5732
# [BS] node=0025 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=10.7044 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=14  bestF=5.1146  gLB=4.5732
# [BS] node=0027 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867419.323557 > v=863503.362077 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=10.2191 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=15  bestF=5.1146  gLB=4.5732
# [BS] node=0029 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867419.323557 > v=863503.362077 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=9.7245 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=16  bestF=5.1146  gLB=4.5732
# [BS] node=0031 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867419.323557 > v=863503.362077 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=6.6886 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=17  bestF=5.1146  gLB=4.5732
# [BS] node=0033 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867419.323557 > v=863503.362077 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=8.2222 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=18  bestF=5.1146  gLB=4.5732
# [BS] node=0035 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867419.323557 > v=863503.362077 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=5.7206 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=19  bestF=5.1146  gLB=4.5732
# [BS] node=0037 olb=4.5732 inner=[9205.17,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [weak_ok] FAIL: v_D=867419.323557 > v=863503.362077 + eps
#   [weak_ok] FAIL: v_D=867027.301349 > v=863049.650947 + eps
#   [LAG_OLB] DISCARDED (lag=5.3522 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=20  bestF=5.1146  gLB=4.5732
# [BS] node=0039 olb=4.5732 inner=[9563.12,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=883793.896184 > v=876804.782966 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=21  bestF=5.1146  gLB=4.5732
# [BS] node=0041 olb=4.5732 inner=[9563.12,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=883793.896184 > v=876804.782966 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=22  bestF=5.1146  gLB=4.5732
# [BS] node=0043 olb=4.5732 inner=[9563.12,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=883793.896184 > v=876804.782966 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=23  bestF=5.1146  gLB=4.5732
# [BS] node=0045 olb=4.5732 inner=[9563.12,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=883793.896184 > v=876804.782966 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=24  bestF=5.1146  gLB=4.5732
# [BS] node=0047 olb=4.5732 inner=[9563.12,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [weak_ok] FAIL: v_D=883793.896184 > v=876804.782966 + eps
#   [weak_ok] FAIL: v_D=876188.483959 > v=870729.452362 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=25  bestF=5.1146  gLB=4.5732
# [BS] node=0049 olb=4.5732 inner=[12296.92,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=895236.383608 > v=885773.491540 + eps
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=26  bestF=5.1146  gLB=4.5732
# [BS] node=0051 olb=4.5732 inner=[12296.92,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=895236.383608 > v=885773.491540 + eps
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=27  bestF=5.1146  gLB=4.5732
# [BS] node=0053 olb=4.5732 inner=[12296.92,895956.26] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=895236.383608 > v=885773.491540 + eps
#   [weak_ok] FAIL: v_D=891400.298131 > v=882790.320748 + eps
#   [LP_OLB] Infeasible node=55
#   [CKPT] saved → bs_14_checkpoint.json  nodes=28  bestF=5.1146  gLB=4.5732
# [BS] node=0056 olb=4.5732 inner=[12296.92,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [LAG_OLB] DISCARDED (lag=6.1666 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=29  bestF=5.1146  gLB=4.5732
# [BS] node=0057 olb=4.5732 inner=[12296.92,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [LAG_OLB] DISCARDED (lag=5.7832 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=30  bestF=5.1146  gLB=4.5732
# [BS] node=0059 olb=4.5732 inner=[12296.92,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [LAG_OLB] DISCARDED (lag=5.5412 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=31  bestF=5.1146  gLB=4.5732
# [BS] node=0061 olb=4.5732 inner=[12296.92,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [LAG_OLB] DISCARDED (lag=5.4491 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=32  bestF=5.1146  gLB=4.5732
# [BS] node=0063 olb=4.5732 inner=[14420.94,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=702785.340897 > v=702737.600606 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [LAG_OLB] DISCARDED (lag=5.3885 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=33  bestF=5.1146  gLB=4.5732
# [BS] node=0065 olb=4.5732 inner=[14420.94,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=702785.340897 > v=702737.600606 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [LAG_OLB] DISCARDED (lag=5.3267 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=34  bestF=5.1146  gLB=4.5732
# [BS] node=0067 olb=4.5732 inner=[14420.94,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=704256.954903 > v=704027.233543 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=35  bestF=5.1146  gLB=4.5732
# [BS] node=0069 olb=4.5732 inner=[14420.94,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=704275.920206 > v=704088.255431 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [LAG_OLB] DISCARDED (lag=5.1389 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=36  bestF=5.1146  gLB=4.5732
# [BS] node=0071 olb=4.5732 inner=[14488.17,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=704275.920206 > v=704088.255431 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=37  bestF=5.1146  gLB=4.5732
# [BS] node=0073 olb=4.5732 inner=[14488.17,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=704275.920206 > v=704088.255431 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=38  bestF=5.1146  gLB=4.5732
# [BS] node=0075 olb=4.5732 inner=[15586.65,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=702785.340897 > v=702737.600606 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=39  bestF=5.1146  gLB=4.5732
# [BS] node=0077 olb=4.5732 inner=[15586.65,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=702785.340897 > v=702737.600606 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=40  bestF=5.1146  gLB=4.5732
# [BS] node=0079 olb=4.5732 inner=[15586.65,728290.33] bestF=5.1146 gLB=4.5732 gap=10.6%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=704256.954903 > v=704027.233543 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=41  bestF=5.1146  gLB=4.5732
# [BS] node=0081 olb=4.5732 inner=[15586.65,728290.33] bestF=5.1146 gLB=4.9912 gap=2.4%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716163.842279 + eps
#   [weak_ok] FAIL: v_D=704275.920206 > v=704088.255431 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=42  bestF=5.1146  gLB=4.5732
# [BS] node=0083 olb=4.5732 inner=[15586.65,728290.33] bestF=5.1146 gLB=4.9307 gap=3.6%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716163.842279 + eps
#   [weak_ok] FAIL: v_D=704275.920206 > v=704088.255431 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=43  bestF=5.1146  gLB=4.5732
# [BS] node=0085 olb=4.5732 inner=[16170.77,728290.33] bestF=5.1146 gLB=4.8804 gap=4.6%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=44  bestF=5.1146  gLB=4.5732
# [BS] node=0087 olb=4.5732 inner=[16170.77,728290.33] bestF=5.1146 gLB=4.8804 gap=4.6%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=45  bestF=5.1146  gLB=4.5732
# [BS] node=0089 olb=4.5732 inner=[16170.77,728290.33] bestF=5.1146 gLB=4.8714 gap=4.8%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=46  bestF=5.1146  gLB=4.5732
# [BS] node=0091 olb=4.5732 inner=[16272.84,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [LP_OLB] Infeasible node=93
#   [CKPT] saved → bs_14_checkpoint.json  nodes=47  bestF=5.1146  gLB=4.5732
# [BS] node=0094 olb=4.5732 inner=[16272.84,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=48  bestF=5.1146  gLB=4.5732
# [BS] node=0095 olb=4.5732 inner=[16272.84,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=49  bestF=5.1146  gLB=4.5732
# [BS] node=0097 olb=4.5732 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=50  bestF=5.1146  gLB=4.5732
# [BS] node=0099 olb=4.5732 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [LP_OLB] Infeasible node=101
#   [CKPT] saved → bs_14_checkpoint.json  nodes=51  bestF=5.1146  gLB=4.5732
# [BS] node=0102 olb=4.5732 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=52  bestF=5.1146  gLB=4.5732
# [BS] node=0103 olb=4.5732 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=53  bestF=5.1146  gLB=4.5732
# [BS] node=0105 olb=4.5732 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
#   [LP_OLB] Infeasible node=107
#   [CKPT] saved → bs_14_checkpoint.json  nodes=54  bestF=5.1146  gLB=4.5732
# [BS] node=0108 olb=4.5732 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.6250 gap=9.6%
# [BS] node=0092 olb=4.6250 inner=[16170.77,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=56  bestF=5.1146  gLB=4.6250
# [BS] node=0109 olb=4.6250 inner=[16213.41,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=57  bestF=5.1146  gLB=4.6250
# [BS] node=0111 olb=4.6250 inner=[16213.41,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=58  bestF=5.1146  gLB=4.6250
# [BS] node=0113 olb=4.6250 inner=[16508.83,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=59  bestF=5.1146  gLB=4.6250
# [BS] node=0115 olb=4.6250 inner=[16508.83,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=60  bestF=5.1146  gLB=4.6250
# [BS] node=0117 olb=4.6250 inner=[16534.25,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=61  bestF=5.1146  gLB=4.6250
# [BS] node=0119 olb=4.6250 inner=[16534.25,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=62  bestF=5.1146  gLB=4.6250
# [BS] node=0121 olb=4.6250 inner=[16686.17,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=63  bestF=5.1146  gLB=4.6250
# [BS] node=0123 olb=4.6250 inner=[16700.54,728290.33] bestF=5.1146 gLB=4.6498 gap=9.1%
# [BS] node=0106 olb=4.6498 inner=[16565.76,725442.79] bestF=5.1146 gLB=4.6625 gap=8.8%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=65  bestF=5.1146  gLB=4.6498
# [BS] node=0126 olb=4.6498 inner=[16565.76,725442.79] bestF=5.1146 gLB=4.6625 gap=8.8%
# [BS] node=0104 olb=4.6625 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.6892 gap=8.3%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=67  bestF=5.1146  gLB=4.6625
# [BS] node=0127 olb=4.6625 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.6892 gap=8.3%
#   [LP_OLB] Infeasible node=129
#   [CKPT] saved → bs_14_checkpoint.json  nodes=68  bestF=5.1146  gLB=4.6625
# [BS] node=0130 olb=4.6625 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.6892 gap=8.3%
# [BS] node=0124 olb=4.6892 inner=[16686.17,728290.33] bestF=5.1146 gLB=4.7086 gap=7.9%
# [BS] node=0122 olb=4.7086 inner=[16534.25,725442.79] bestF=5.1146 gLB=4.7115 gap=7.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=71  bestF=5.1146  gLB=4.7086
# [BS] node=0131 olb=4.7086 inner=[16549.88,725442.79] bestF=5.1146 gLB=4.7115 gap=7.9%
# [BS] node=0125 olb=4.7115 inner=[16581.65,725442.79] bestF=5.1146 gLB=4.7144 gap=7.8%
# [BS] node=0120 olb=4.7144 inner=[16534.25,728290.33] bestF=5.1146 gLB=4.7217 gap=7.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=74  bestF=5.1146  gLB=4.7144
# [BS] node=0133 olb=4.7144 inner=[16686.17,728290.33] bestF=5.1146 gLB=4.7217 gap=7.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=75  bestF=5.1146  gLB=4.7144
# [BS] node=0135 olb=4.7144 inner=[16700.54,728290.33] bestF=5.1146 gLB=4.7217 gap=7.7%
# [BS] node=0100 olb=4.7217 inner=[16565.76,727933.16] bestF=5.1146 gLB=4.7267 gap=7.6%
#   [LP_OLB] Infeasible node=137
#   [CKPT] saved → bs_14_checkpoint.json  nodes=77  bestF=5.1146  gLB=4.7217
# [BS] node=0138 olb=4.7217 inner=[16565.76,727933.16] bestF=5.1146 gLB=4.7267 gap=7.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=78  bestF=5.1146  gLB=4.7217
# [BS] node=0139 olb=4.7217 inner=[16565.76,727933.16] bestF=5.1146 gLB=4.7267 gap=7.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=79  bestF=5.1146  gLB=4.7217
# [BS] node=0141 olb=4.7217 inner=[16716.43,727933.16] bestF=5.1146 gLB=4.7267 gap=7.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=80  bestF=5.1146  gLB=4.7217
# [BS] node=0144 olb=4.7217 inner=[16716.43,727933.16] bestF=5.1146 gLB=4.7267 gap=7.6%
# [BS] node=0098 olb=4.7267 inner=[16272.84,722595.24] bestF=5.1146 gLB=4.7392 gap=7.3%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=82  bestF=5.1146  gLB=4.7267
# [BS] node=0145 olb=4.7267 inner=[16272.84,722595.24] bestF=5.1146 gLB=4.7392 gap=7.3%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [LP_OLB] Infeasible node=147
#   [CKPT] saved → bs_14_checkpoint.json  nodes=83  bestF=5.1146  gLB=4.7267
# [BS] node=0148 olb=4.7267 inner=[16272.84,722595.24] bestF=5.1146 gLB=4.7392 gap=7.3%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=84  bestF=5.1146  gLB=4.7267
# [BS] node=0149 olb=4.7267 inner=[16272.84,722595.24] bestF=5.1146 gLB=4.7392 gap=7.3%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=85  bestF=5.1146  gLB=4.7267
# [BS] node=0151 olb=4.7267 inner=[16418.75,722595.24] bestF=5.1146 gLB=4.7392 gap=7.3%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=86  bestF=5.1146  gLB=4.7267
# [BS] node=0153 olb=4.7267 inner=[16434.64,722595.24] bestF=5.1146 gLB=4.7280 gap=7.6%
# [BS] node=0154 olb=4.7280 inner=[16418.75,722595.24] bestF=5.1146 gLB=4.7392 gap=7.3%
# [BS] node=0128 olb=4.7392 inner=[16565.76,725442.79] bestF=5.1146 gLB=4.7519 gap=7.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=89  bestF=5.1146  gLB=4.7392
# [BS] node=0156 olb=4.7392 inner=[16565.76,725442.79] bestF=5.1146 gLB=4.7519 gap=7.1%
# [BS] node=0096 olb=4.7519 inner=[16272.84,728290.33] bestF=5.1146 gLB=4.7534 gap=7.1%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=91  bestF=5.1146  gLB=4.7519
# [BS] node=0157 olb=4.7519 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.7534 gap=7.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=92  bestF=5.1146  gLB=4.7519
# [BS] node=0159 olb=4.7519 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.7534 gap=7.1%
#   [LP_OLB] Infeasible node=161
#   [CKPT] saved → bs_14_checkpoint.json  nodes=93  bestF=5.1146  gLB=4.7519
# [BS] node=0162 olb=4.7519 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.7534 gap=7.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=94  bestF=5.1146  gLB=4.7519
# [BS] node=0163 olb=4.7519 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.7534 gap=7.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=95  bestF=5.1146  gLB=4.7519
# [BS] node=0165 olb=4.7519 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.7534 gap=7.1%
#   [LP_OLB] Infeasible node=167
#   [CKPT] saved → bs_14_checkpoint.json  nodes=96  bestF=5.1146  gLB=4.7519
# [BS] node=0168 olb=4.7519 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.7534 gap=7.1%
# [BS] node=0118 olb=4.7534 inner=[16508.83,728290.33] bestF=5.1146 gLB=4.7728 gap=6.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=98  bestF=5.1146  gLB=4.7534
# [BS] node=0169 olb=4.7534 inner=[16508.83,728290.33] bestF=5.1146 gLB=4.7728 gap=6.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=99  bestF=5.1146  gLB=4.7534
# [BS] node=0171 olb=4.7534 inner=[16660.75,728290.33] bestF=5.1146 gLB=4.7728 gap=6.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=100  bestF=5.1146  gLB=4.7534
# [BS] node=0173 olb=4.7534 inner=[16673.46,728290.33] bestF=5.1146 gLB=4.7728 gap=6.7%
# [BS] node=0132 olb=4.7728 inner=[16534.25,725442.79] bestF=5.1146 gLB=4.7769 gap=6.6%
# [BS] node=0116 olb=4.7769 inner=[16508.83,727933.16] bestF=5.1146 gLB=4.7786 gap=6.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=103  bestF=5.1146  gLB=4.7769
# [BS] node=0175 olb=4.7769 inner=[16534.25,727933.16] bestF=5.1146 gLB=4.7786 gap=6.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=104  bestF=5.1146  gLB=4.7769
# [BS] node=0177 olb=4.7769 inner=[16534.25,727933.16] bestF=5.1146 gLB=4.7786 gap=6.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=105  bestF=5.1146  gLB=4.7769
# [BS] node=0179 olb=4.7769 inner=[16686.17,727933.16] bestF=5.1146 gLB=4.7786 gap=6.6%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=106  bestF=5.1146  gLB=4.7769
# [BS] node=0181 olb=4.7769 inner=[16700.54,727933.16] bestF=5.1146 gLB=4.7786 gap=6.6%
# [BS] node=0136 olb=4.7786 inner=[16686.17,728290.33] bestF=5.1146 gLB=4.7922 gap=6.3%
# [BS] node=0114 olb=4.7922 inner=[16213.41,722595.24] bestF=5.1146 gLB=4.7980 gap=6.2%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718370.249133 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=109  bestF=5.1146  gLB=4.7922
# [BS] node=0183 olb=4.7922 inner=[16213.41,722595.24] bestF=5.1146 gLB=4.7980 gap=6.2%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718370.249133 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=110  bestF=5.1146  gLB=4.7922
# [BS] node=0185 olb=4.7922 inner=[16241.06,722595.24] bestF=5.1146 gLB=4.7980 gap=6.2%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718370.249133 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=111  bestF=5.1146  gLB=4.7922
# [BS] node=0187 olb=4.7922 inner=[16241.06,722595.24] bestF=5.1146 gLB=4.7980 gap=6.2%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718370.249133 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=112  bestF=5.1146  gLB=4.7922
# [BS] node=0189 olb=4.7922 inner=[16386.97,722595.24] bestF=5.1146 gLB=4.7980 gap=6.2%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=113  bestF=5.1146  gLB=4.7922
# [BS] node=0191 olb=4.7922 inner=[16402.86,722595.24] bestF=5.1146 gLB=4.7980 gap=6.2%
# [BS] node=0134 olb=4.7980 inner=[16534.25,725442.79] bestF=5.1146 gLB=4.7982 gap=6.2%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=115  bestF=5.1146  gLB=4.7980
# [BS] node=0193 olb=4.7980 inner=[16549.88,725442.79] bestF=5.1146 gLB=4.7982 gap=6.2%
# [BS] node=0142 olb=4.7982 inner=[16565.76,725085.62] bestF=5.1146 gLB=4.8009 gap=6.1%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=117  bestF=5.1146  gLB=4.7982
# [BS] node=0196 olb=4.7982 inner=[16565.76,725085.62] bestF=5.1146 gLB=4.8009 gap=6.1%
# [BS] node=0155 olb=4.8009 inner=[16581.65,725442.79] bestF=5.1146 gLB=4.8035 gap=6.1%
# [BS] node=0152 olb=4.8035 inner=[16272.84,719747.70] bestF=5.1146 gLB=4.8037 gap=6.1%
#   [weak_ok] FAIL: v_D=725512.634526 > v=718119.861052 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=737372.675070 > v=719035.812949 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=723562.998100 > v=717612.040852 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=120  bestF=5.1146  gLB=4.8035
# [BS] node=0197 olb=4.8035 inner=[16289.45,719747.70] bestF=5.1146 gLB=4.8037 gap=6.1%
#   [weak_ok] FAIL: v_D=725512.634526 > v=718119.861052 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=737372.675070 > v=719035.812949 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=723562.998100 > v=717612.040852 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
# [BS] node=0112 olb=4.8037 inner=[16213.41,728290.33] bestF=5.1146 gLB=4.8111 gap=5.9%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=122  bestF=5.1146  gLB=4.8037
# [BS] node=0199 olb=4.8037 inner=[16508.83,728290.33] bestF=5.1146 gLB=4.8111 gap=5.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=123  bestF=5.1146  gLB=4.8037
# [BS] node=0201 olb=4.8037 inner=[16508.83,728290.33] bestF=5.1146 gLB=4.8111 gap=5.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=124  bestF=5.1146  gLB=4.8037
# [BS] node=0203 olb=4.8037 inner=[16534.25,728290.33] bestF=5.1146 gLB=4.8111 gap=5.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=125  bestF=5.1146  gLB=4.8037
# [BS] node=0205 olb=4.8037 inner=[16534.25,728290.33] bestF=5.1146 gLB=4.8111 gap=5.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=126  bestF=5.1146  gLB=4.8037
# [BS] node=0207 olb=4.8037 inner=[16686.17,728290.33] bestF=5.1146 gLB=4.8111 gap=5.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=127  bestF=5.1146  gLB=4.8037
# [BS] node=0209 olb=4.8037 inner=[16700.54,728290.33] bestF=5.1146 gLB=4.8111 gap=5.9%
# [BS] node=0140 olb=4.8111 inner=[16565.76,727933.16] bestF=5.1146 gLB=4.8116 gap=5.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=129  bestF=5.1146  gLB=4.8111
# [BS] node=0211 olb=4.8111 inner=[16716.43,727933.16] bestF=5.1146 gLB=4.8116 gap=5.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=130  bestF=5.1146  gLB=4.8111
# [BS] node=0214 olb=4.8111 inner=[16716.43,727933.16] bestF=5.1146 gLB=4.8116 gap=5.9%
# [BS] node=0198 olb=4.8116 inner=[16272.84,719747.70] bestF=5.1146 gLB=4.8160 gap=5.8%
#   [weak_ok] FAIL: v_D=725512.634526 > v=718119.861052 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=737094.095766 > v=719035.812949 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=723562.998100 > v=717612.040852 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
# [BS] node=0150 olb=4.8160 inner=[16272.84,722595.24] bestF=5.1146 gLB=4.8177 gap=5.8%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=133  bestF=5.1146  gLB=4.8160
# [BS] node=0215 olb=4.8160 inner=[16418.75,722595.24] bestF=5.1146 gLB=4.8177 gap=5.8%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=134  bestF=5.1146  gLB=4.8160
# [BS] node=0217 olb=4.8160 inner=[16434.64,722595.24] bestF=5.1146 gLB=4.8174 gap=5.8%
# [BS] node=0218 olb=4.8174 inner=[16418.75,722595.24] bestF=5.1146 gLB=4.8177 gap=5.8%
# [BS] node=0174 olb=4.8177 inner=[16660.75,728290.33] bestF=5.1146 gLB=4.8192 gap=5.8%
# [BS] node=0195 olb=4.8192 inner=[16581.65,725085.62] bestF=5.1146 gLB=4.8286 gap=5.6%
# [BS] node=0166 olb=4.8286 inner=[16565.76,725442.79] bestF=5.1146 gLB=4.8371 gap=5.4%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=139  bestF=5.1146  gLB=4.8286
# [BS] node=0220 olb=4.8286 inner=[16565.76,725442.79] bestF=5.1146 gLB=4.8371 gap=5.4%
# [BS] node=0172 olb=4.8371 inner=[16508.83,725442.79] bestF=5.1146 gLB=4.8412 gap=5.3%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=141  bestF=5.1146  gLB=4.8371
# [BS] node=0221 olb=4.8371 inner=[16521.54,725442.79] bestF=5.1146 gLB=4.8412 gap=5.3%
# [BS] node=0182 olb=4.8412 inner=[16686.17,727933.16] bestF=5.1146 gLB=4.8413 gap=5.3%
# [BS] node=0164 olb=4.8413 inner=[16565.76,728290.33] bestF=5.1146 gLB=4.8428 gap=5.3%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=144  bestF=5.1146  gLB=4.8413
# [BS] node=0223 olb=4.8413 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.8428 gap=5.3%
#   [LP_OLB] Infeasible node=225
#   [CKPT] saved → bs_14_checkpoint.json  nodes=145  bestF=5.1146  gLB=4.8413
# [BS] node=0226 olb=4.8413 inner=[16716.43,728290.33] bestF=5.1146 gLB=4.8428 gap=5.3%
# [BS] node=0170 olb=4.8428 inner=[16508.83,728290.33] bestF=5.1146 gLB=4.8565 gap=5.0%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=147  bestF=5.1146  gLB=4.8428
# [BS] node=0227 olb=4.8428 inner=[16660.75,728290.33] bestF=5.1146 gLB=4.8565 gap=5.0%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=148  bestF=5.1146  gLB=4.8428
# [BS] node=0229 olb=4.8428 inner=[16673.46,728290.33] bestF=5.1146 gLB=4.8565 gap=5.0%
# [BS] node=0192 olb=4.8565 inner=[16386.97,722595.24] bestF=5.1146 gLB=4.8605 gap=5.0%
# [BS] node=0180 olb=4.8605 inner=[16534.25,725085.62] bestF=5.1146 gLB=4.8622 gap=4.9%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=151  bestF=5.1146  gLB=4.8605
# [BS] node=0231 olb=4.8605 inner=[16549.88,725085.62] bestF=5.1146 gLB=4.8622 gap=4.9%
# [BS] node=0194 olb=4.8622 inner=[16534.25,725442.79] bestF=5.1146 gLB=4.8663 gap=4.9%
# [BS] node=0178 olb=4.8663 inner=[16534.25,727933.16] bestF=5.1146 gLB=4.8680 gap=4.8%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=154  bestF=5.1146  gLB=4.8663
# [BS] node=0233 olb=4.8663 inner=[16686.17,727933.16] bestF=5.1146 gLB=4.8680 gap=4.8%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=155  bestF=5.1146  gLB=4.8663
# [BS] node=0235 olb=4.8663 inner=[16700.54,727933.16] bestF=5.1146 gLB=4.8680 gap=4.8%
# [BS] node=0210 olb=4.8680 inner=[16686.17,728290.33] bestF=5.1146 gLB=4.8714 gap=4.8%
# [BS] node=0090 olb=4.8714 inner=[16170.77,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=743899.002527 > v=719033.356431 + eps
#   [weak_ok] FAIL: v_D=719539.325360 > v=716190.290026 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=158  bestF=5.1146  gLB=4.8714
# [BS] node=0237 olb=4.8714 inner=[16272.84,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=743899.002527 > v=719033.356431 + eps
#   [weak_ok] FAIL: v_D=719539.325360 > v=716190.290026 + eps
#   [LP_OLB] Infeasible node=239
#   [CKPT] saved → bs_14_checkpoint.json  nodes=159  bestF=5.1146  gLB=4.8714
# [BS] node=0240 olb=4.8714 inner=[16272.84,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=738883.859272 > v=719033.356431 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716186.743123 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=160  bestF=5.1146  gLB=4.8714
# [BS] node=0241 olb=4.8714 inner=[16272.84,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [weak_ok] FAIL: v_D=718566.250983 > v=715433.677373 + eps
#   [weak_ok] FAIL: v_D=738883.859272 > v=719033.356431 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716186.743123 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=161  bestF=5.1146  gLB=4.8714
# [BS] node=0243 olb=4.8714 inner=[16565.76,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=162  bestF=5.1146  gLB=4.8714
# [BS] node=0245 olb=4.8714 inner=[16565.76,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [LP_OLB] Infeasible node=247
#   [CKPT] saved → bs_14_checkpoint.json  nodes=163  bestF=5.1146  gLB=4.8714
# [BS] node=0248 olb=4.8714 inner=[16565.76,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=164  bestF=5.1146  gLB=4.8714
# [BS] node=0249 olb=4.8714 inner=[16565.76,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=165  bestF=5.1146  gLB=4.8714
# [BS] node=0251 olb=4.8714 inner=[16716.43,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=166  bestF=5.1146  gLB=4.8714
# [BS] node=0254 olb=4.8714 inner=[16716.43,727575.99] bestF=5.1146 gLB=4.8750 gap=4.7%
# [BS] node=0146 olb=4.8750 inner=[16272.84,722238.07] bestF=5.1146 gLB=4.8759 gap=4.7%
#   [weak_ok] FAIL: v_D=747362.991436 > v=719182.951616 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=724831.548239 > v=717966.755617 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [LP_OLB] Infeasible node=255
#   [CKPT] saved → bs_14_checkpoint.json  nodes=168  bestF=5.1146  gLB=4.8750
# [BS] node=0256 olb=4.8750 inner=[16272.84,722238.07] bestF=5.1146 gLB=4.8759 gap=4.7%
#   [weak_ok] FAIL: v_D=747353.745547 > v=719182.951616 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=724831.548239 > v=717966.755617 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=169  bestF=5.1146  gLB=4.8750
# [BS] node=0257 olb=4.8750 inner=[16272.84,722238.07] bestF=5.1146 gLB=4.8759 gap=4.7%
#   [weak_ok] FAIL: v_D=747353.745547 > v=719182.951616 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=724831.548239 > v=717966.755617 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=170  bestF=5.1146  gLB=4.8750
# [BS] node=0259 olb=4.8750 inner=[16418.75,722238.07] bestF=5.1146 gLB=4.8759 gap=4.7%
#   [weak_ok] FAIL: v_D=736361.085127 > v=718981.484849 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=171  bestF=5.1146  gLB=4.8750
# [BS] node=0261 olb=4.8750 inner=[16434.64,722238.07] bestF=5.1146 gLB=4.8759 gap=4.7%
#   [weak_ok] FAIL: v_D=736374.214923 > v=718981.484849 + eps
# [BS] node=0190 olb=4.8759 inner=[16241.06,719747.70] bestF=5.1146 gLB=4.8799 gap=4.6%
#   [weak_ok] FAIL: v_D=725512.634526 > v=718119.861052 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=737080.737582 > v=719035.812949 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718370.249133 + eps
#   [weak_ok] FAIL: v_D=723562.998100 > v=717612.040852 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=173  bestF=5.1146  gLB=4.8759
# [BS] node=0263 olb=4.8759 inner=[16256.95,719747.70] bestF=5.1146 gLB=4.8799 gap=4.6%
#   [weak_ok] FAIL: v_D=725512.634526 > v=718119.861052 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=737080.737582 > v=719035.812949 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718370.249133 + eps
#   [weak_ok] FAIL: v_D=723562.998100 > v=717612.040852 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
# [BS] node=0262 olb=4.8799 inner=[16418.75,722238.07] bestF=5.1146 gLB=4.8804 gap=4.6%
#   [weak_ok] FAIL: v_D=736361.085127 > v=718981.484849 + eps
# [BS] node=0086 olb=4.8804 inner=[15586.65,716904.63] bestF=5.1146 gLB=4.8816 gap=4.6%
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=711950.728572 > v=710483.451715 + eps
#   [weak_ok] FAIL: v_D=704275.920206 > v=704088.255431 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716893.093848 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716881.555103 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716870.016358 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716858.686966 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=716871.154335 > v=714069.910298 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=709329.469200 > v=708400.820224 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=720238.372058 > v=716547.461309 + eps
#   [weak_ok] FAIL: v_D=719539.325360 > v=716190.290026 + eps
#   [weak_ok] FAIL: v_D=719014.961075 > v=715833.118742 + eps
#   [weak_ok] FAIL: v_D=718593.945907 > v=715482.495139 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=176  bestF=5.1146  gLB=4.8804
# [BS] node=0265 olb=4.8804 inner=[15586.65,716904.63] bestF=5.1146 gLB=4.8816 gap=4.6%
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=711950.728572 > v=710483.451715 + eps
#   [weak_ok] FAIL: v_D=704275.920206 > v=704088.255431 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716893.093848 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716881.555103 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716870.016358 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716858.686966 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=716871.154335 > v=714069.910298 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=709329.469200 > v=708400.820224 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=720238.372058 > v=716547.461309 + eps
#   [weak_ok] FAIL: v_D=719539.325360 > v=716190.290026 + eps
#   [weak_ok] FAIL: v_D=719014.961075 > v=715833.118742 + eps
#   [weak_ok] FAIL: v_D=718593.945907 > v=715482.495139 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=177  bestF=5.1146  gLB=4.8804
# [BS] node=0267 olb=4.8804 inner=[15586.65,716904.63] bestF=5.1146 gLB=4.8816 gap=4.6%
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=712378.476433 > v=710840.529641 + eps
#   [weak_ok] FAIL: v_D=705072.266138 > v=704787.348760 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716893.093848 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716881.555103 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716870.016358 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716858.686966 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=716871.154335 > v=714069.910298 + eps
#   [weak_ok] FAIL: v_D=712840.339298 > v=711235.188003 + eps
#   [weak_ok] FAIL: v_D=709329.469200 > v=708400.820224 + eps
#   [weak_ok] FAIL: v_D=705942.796863 > v=705566.474278 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=720628.334632 > v=716726.046951 + eps
#   [weak_ok] FAIL: v_D=720238.372058 > v=716547.461309 + eps
#   [weak_ok] FAIL: v_D=719884.424829 > v=716368.875668 + eps
#   [weak_ok] FAIL: v_D=719539.325360 > v=716190.290026 + eps
#   [CKPT] saved → bs_14_checkpoint.json  nodes=178  bestF=5.1146  gLB=4.8804
# [BS] node=0269 olb=4.8804 inner=[15704.43,716904.63] bestF=5.1146 gLB=4.8816 gap=4.6%
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721119.420729 > v=716904.632593 + eps
#   [weak_ok] FAIL: v_D=712378.476433 > v=710840.529641 + eps
#   [weak_ok] FAIL: v_D=705072.266138 > v=704787.348760 + eps
# ...
#   [weak_ok] FAIL: v_D=719628.676281 > v=716276.035944 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716186.743123 + eps
#   [LAG_OLB] DISCARDED (lag=5.2008 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=703  bestF=5.1146  gLB=5.1114
# [BS] node=0939 olb=5.1114 inner=[15952.45,716543.91] bestF=5.1146 gLB=5.1116 gap=0.1%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=716028.326429 > v=713502.138023 + eps
#   [weak_ok] FAIL: v_D=711931.763270 > v=710461.042814 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716532.463985 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716521.013563 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716509.619880 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=718133.566132 > v=715123.652559 + eps
#   [weak_ok] FAIL: v_D=716242.200359 > v=713703.390712 + eps
#   [weak_ok] FAIL: v_D=714175.388558 > v=712283.128865 + eps
#   [weak_ok] FAIL: v_D=712397.441736 > v=710862.938542 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=719975.067467 > v=716454.621586 + eps
#   [weak_ok] FAIL: v_D=719801.226016 > v=716365.328765 + eps
#   [weak_ok] FAIL: v_D=719628.676281 > v=716276.035944 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716186.743123 + eps
#   [LAG_OLB] DISCARDED (lag=5.1951 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=704  bestF=5.1146  gLB=5.1114
# [BS] node=0941 olb=5.1114 inner=[16095.15,716543.91] bestF=5.1146 gLB=5.1116 gap=0.1%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=717919.692201 > v=714922.211696 + eps
#   [weak_ok] FAIL: v_D=715791.921427 > v=713301.190159 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716532.463985 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716521.013563 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716509.619880 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=718979.249018 > v=715833.783483 + eps
#   [weak_ok] FAIL: v_D=718133.566132 > v=715123.652559 + eps
#   [weak_ok] FAIL: v_D=717287.883245 > v=714413.521636 + eps
#   [weak_ok] FAIL: v_D=716242.200359 > v=713703.390712 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=719975.067467 > v=716454.621586 + eps
#   [weak_ok] FAIL: v_D=719801.226016 > v=716365.328765 + eps
#   [weak_ok] FAIL: v_D=719628.676281 > v=716276.035944 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716186.743123 + eps
#   [LAG_OLB] DISCARDED (lag=5.1757 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=705  bestF=5.1146  gLB=5.1114
# [BS] node=0943 olb=5.1114 inner=[16111.03,716543.91] bestF=5.1146 gLB=5.1116 gap=0.1%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=717919.692201 > v=714922.211696 + eps
#   [weak_ok] FAIL: v_D=715791.921427 > v=713301.190159 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716532.463985 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716521.013563 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716509.619880 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=718979.249018 > v=715833.783483 + eps
#   [weak_ok] FAIL: v_D=718133.566132 > v=715123.652559 + eps
#   [weak_ok] FAIL: v_D=717287.883245 > v=714413.521636 + eps
#   [weak_ok] FAIL: v_D=716242.200359 > v=713703.390712 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
#   [weak_ok] FAIL: v_D=719975.067467 > v=716454.621586 + eps
#   [weak_ok] FAIL: v_D=719801.226016 > v=716365.328765 + eps
#   [weak_ok] FAIL: v_D=719628.676281 > v=716276.035944 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716186.743123 + eps
# [BS] node=0428 olb=5.1116 inner=[16213.41,722595.24] bestF=5.1146 gLB=5.1117 gap=0.1%
#   [weak_ok] FAIL: v_D=719456.126547 > v=716141.337504 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [LAG_OLB] DISCARDED (lag=5.2635 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=707  bestF=5.1146  gLB=5.1116
# [BS] node=0945 olb=5.1116 inner=[16213.41,722595.24] bestF=5.1146 gLB=5.1117 gap=0.1%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [LAG_OLB] DISCARDED (lag=5.2400 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=708  bestF=5.1146  gLB=5.1116
# [BS] node=0947 olb=5.1116 inner=[16241.06,722595.24] bestF=5.1146 gLB=5.1117 gap=0.1%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [LAG_OLB] DISCARDED (lag=5.2010 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=709  bestF=5.1146  gLB=5.1116
# [BS] node=0949 olb=5.1116 inner=[16241.06,722595.24] bestF=5.1146 gLB=5.1117 gap=0.1%
#   [weak_ok] FAIL: v_D=720156.391779 > v=716498.415430 + eps
#   [weak_ok] FAIL: v_D=726515.923847 > v=718323.926900 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [LAG_OLB] DISCARDED (lag=5.1952 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=710  bestF=5.1146  gLB=5.1116
# [BS] node=0951 olb=5.1116 inner=[16386.97,722595.24] bestF=5.1146 gLB=5.1117 gap=0.1%
#   [LAG_OLB] DISCARDED (lag=5.1758 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=711  bestF=5.1146  gLB=5.1116
# [BS] node=0953 olb=5.1116 inner=[16402.86,722595.24] bestF=5.1146 gLB=5.1117 gap=0.1%
# [BS] node=0652 olb=5.1117 inner=[15704.43,708379.87] bestF=5.1146 gLB=5.1129 gap=0.0%
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=707315.362403 > v=706758.847586 + eps
#   [weak_ok] FAIL: v_D=705480.607927 > v=705144.426686 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709303.776773 > v=708368.664672 + eps
#   [weak_ok] FAIL: v_D=709299.035447 > v=708357.460221 + eps
#   [weak_ok] FAIL: v_D=709295.939741 > v=708346.255770 + eps
#   [weak_ok] FAIL: v_D=709295.595474 > v=708338.866779 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=708369.129819 > v=707669.832286 + eps
#   [weak_ok] FAIL: v_D=707538.498600 > v=706959.795450 + eps
#   [weak_ok] FAIL: v_D=706727.271481 > v=706249.758613 + eps
#   [weak_ok] FAIL: v_D=705916.044361 > v=705539.721777 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709201.581133 > v=708290.599641 + eps
#   [weak_ok] FAIL: v_D=709094.644168 > v=708201.330159 + eps
#   [weak_ok] FAIL: v_D=708987.707203 > v=708112.060678 + eps
#   [weak_ok] FAIL: v_D=708880.770238 > v=708022.791197 + eps
#   [LP_OLB] Infeasible node=955
#   [CKPT] saved → bs_14_checkpoint.json  nodes=713  bestF=5.1146  gLB=5.1117
# [BS] node=0956 olb=5.1117 inner=[15704.43,708379.87] bestF=5.1146 gLB=5.1129 gap=0.0%
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=707315.362403 > v=706758.847586 + eps
#   [weak_ok] FAIL: v_D=705480.607927 > v=705144.426686 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709303.776773 > v=708368.664672 + eps
#   [weak_ok] FAIL: v_D=709299.035447 > v=708357.460221 + eps
#   [weak_ok] FAIL: v_D=709295.939741 > v=708346.255770 + eps
#   [weak_ok] FAIL: v_D=709295.595474 > v=708338.866779 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708401.619602 + eps
#   [weak_ok] FAIL: v_D=708369.129819 > v=707669.832286 + eps
#   [weak_ok] FAIL: v_D=707538.498600 > v=706959.795450 + eps
#   [weak_ok] FAIL: v_D=706727.271481 > v=706249.758613 + eps
#   [weak_ok] FAIL: v_D=705916.044361 > v=705539.721777 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709201.581133 > v=708290.599641 + eps
#   [weak_ok] FAIL: v_D=709094.644168 > v=708201.330159 + eps
#   [weak_ok] FAIL: v_D=708987.707203 > v=708112.060678 + eps
#   [weak_ok] FAIL: v_D=708880.770238 > v=708022.791197 + eps
#   [LAG_OLB] DISCARDED (lag=5.1461 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=714  bestF=5.1146  gLB=5.1117
# [BS] node=0957 olb=5.1117 inner=[15723.50,708379.87] bestF=5.1146 gLB=5.1129 gap=0.0%
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=707315.362403 > v=706758.847586 + eps
#   [weak_ok] FAIL: v_D=705480.607927 > v=705144.426686 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709303.776773 > v=708368.664672 + eps
#   [weak_ok] FAIL: v_D=709299.035447 > v=708357.460221 + eps
#   [weak_ok] FAIL: v_D=709295.939741 > v=708346.255770 + eps
#   [weak_ok] FAIL: v_D=709295.595474 > v=708338.866779 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708401.619602 + eps
#   [weak_ok] FAIL: v_D=708369.129819 > v=707669.832286 + eps
#   [weak_ok] FAIL: v_D=707538.498600 > v=706959.795450 + eps
#   [weak_ok] FAIL: v_D=706727.271481 > v=706249.758613 + eps
#   [weak_ok] FAIL: v_D=705916.044361 > v=705539.721777 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709308.518099 > v=708379.869122 + eps
#   [weak_ok] FAIL: v_D=709201.581133 > v=708290.599641 + eps
#   [weak_ok] FAIL: v_D=709094.644168 > v=708201.330159 + eps
#   [weak_ok] FAIL: v_D=708987.707203 > v=708112.060678 + eps
#   [weak_ok] FAIL: v_D=708880.770238 > v=708022.791197 + eps
# [BS] node=0614 olb=5.1129 inner=[16272.84,721880.90] bestF=5.1146 gLB=5.1131 gap=0.0%
#   [weak_ok] FAIL: v_D=730325.748507 > v=718825.780333 + eps
#   [weak_ok] FAIL: v_D=718969.602439 > v=715784.259579 + eps
#   [weak_ok] FAIL: v_D=736625.550416 > v=719033.356431 + eps
#   [weak_ok] FAIL: v_D=723476.494105 > v=717609.584334 + eps
#   [weak_ok] FAIL: v_D=719456.126547 > v=716186.743123 + eps
#   [LAG_OLB] DISCARDED (lag=5.1407 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=716  bestF=5.1146  gLB=5.1129
# [BS] node=0959 olb=5.1129 inner=[16418.75,721880.90] bestF=5.1146 gLB=5.1131 gap=0.0%
#   [weak_ok] FAIL: v_D=728825.297114 > v=718624.406924 + eps
#   [weak_ok] FAIL: v_D=736625.550416 > v=719033.356431 + eps
#   [LAG_OLB] DISCARDED (lag=5.1213 > bestF=5.1146)
#   [CKPT] saved → bs_14_checkpoint.json  nodes=717  bestF=5.1146  gLB=5.1129
# [BS] node=0961 olb=5.1129 inner=[16434.64,721880.90] bestF=5.1146 gLB=5.1131 gap=0.0%
#   [weak_ok] FAIL: v_D=728831.981598 > v=718624.406924 + eps
#   [weak_ok] FAIL: v_D=736625.550416 > v=719033.356431 + eps
# [BS] node=0708 olb=5.1131 inner=[16095.15,716901.09] bestF=5.1146 gLB=5.1134 gap=0.0%
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=718347.440062 > v=715279.337357 + eps
#   [weak_ok] FAIL: v_D=716242.200359 > v=713658.268085 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716889.635268 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716878.184846 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716866.734424 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716855.493355 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=719489.311596 > v=716190.954766 + eps
#   [weak_ok] FAIL: v_D=718561.313992 > v=715480.823843 + eps
#   [weak_ok] FAIL: v_D=717715.631106 > v=714770.692919 + eps
#   [weak_ok] FAIL: v_D=716869.948220 > v=714060.561995 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=721078.887449 > v=716901.085690 + eps
#   [weak_ok] FAIL: v_D=720797.446276 > v=716811.792869 + eps
#   [weak_ok] FAIL: v_D=720553.793868 > v=716722.500048 + eps
#   [weak_ok] FAIL: v_D=720354.441142 > v=716633.207228 + eps
#   [weak_ok] FAIL: v_D=720156.391779 > v=716543.914407 + eps
# [BS] node=0718 olb=5.1134 inner=[16335.15,722595.24] bestF=5.1146 gLB=5.1134 gap=0.0%
#   [CKPT] saved → bs_14_checkpoint.json  nodes=720  bestF=5.1146  gLB=5.1146
#
# IEEE 14-bus  certified=False  gap=0.0000  nodes=720

# %%
# ── Plot — IEEE 14-bus ──────────────────────────────────────────────────────
assert res_bs_14.get("success") and res_bs_14.get("b_hat") is not None, \
    "No incumbent for IEEE 14-bus."

b_hat_14 = np.array(res_bs_14["b_hat"], dtype=float)

_,_ , sol_plain_hat_14 = oracle_14.solve_plain(b_hat_14)
_, _,  sol_foil_hat_14 = oracle_14.solve_foil(b_hat_14)

plot_bs_results(
    DATA_14, b0_14, b_hat_14,
    sol0=solF_14,
    sol_plain_hat=sol_plain_hat_14,
    sol_foil_hat=sol_foil_hat_14,
    res_bs=res_bs_14,
    label="IEEE 14-bus",
    foil_label=f"emissions −{ALPHA:.0%}",
)
# Out:
# IEEE 14-bus — B&S summary:
#   Nodes processed : 720
#   F_opt (incumbent): 5.114624
#   Global LB        : 5.114624
#   Gap              : 0.000%
#   Certified        : False
#    ell  fr->to     b0(MW)   b_hat(MW)     Δ(MW)   b_hat(pu)     Δ(pu)    util
#     15   8->9       39.000      78.000    39.000       2.000    +1.000   1.000
#     14   6->8       39.000      46.312     7.312       1.188    +0.188   1.000

# %% [markdown]
# ### 3.3 · IEEE 30-bus

# %%
# ── Branch-and-Sandwich — IEEE 30-bus ──────────────────────────────────────
assert solFoil_b0_30 is not None, \
    "Foil is infeasible at b0 for IEEE 30-bus — check emissions data."

def _make_emission_viol_fn_30():
    E_f  = E_factual_30
    tgt  = (1 - ALPHA) * E_f
    e_g  = e_30
    def viol_fn(m, var, idx):
        s = m.addVar(lb=0.0, name="emis_viol")
        total_emis = gp.quicksum(
            e_g[g] * var["p"][g, t]
            for g in range(len(e_g))
            for t in range(int(DATA_30.T))
        )
        m.addConstr(s >= (total_emis - tgt) / max(E_f, 1.0), name="emis_viol_constr")
        m.update()
        return s
    return viol_fn

viol_fn_30 = _make_emission_viol_fn_30()

bs_30 = UCBranchAndSandwichWCE_4b(
    oracle=oracle_30,
    data=DATA_30, idx=idx_30, cvec=cvec_30,
    foil_extra_constr_fn=foil_fn_30,
    b0=b0_30,
    b_bounds=(bL_30, bU_30),
    b_free_idx=b_free_idx_30,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_30,
    foil_violation_expr_fn=viol_fn_30,
    lagrange_penalty=200.0,
)

res_bs_30 = bs_30.run(
    window_size=int(DATA_30.T),
    per_bus_neutrality=True,
    u_init=u_init_30, p_init=p_init_30,
    on_t=on_t_30, off_t=off_t_30,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\nIEEE 30-bus  certified={res_bs_30['certified']}  "
      f"gap={res_bs_30.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_30.get('nodes')}")

# %%
# ── Plot — IEEE 30-bus ──────────────────────────────────────────────────────
assert res_bs_30.get("success") and res_bs_30.get("b_hat") is not None, \
    "No incumbent for IEEE 30-bus."

b_hat_30 = np.array(res_bs_30["b_hat"], dtype=float)

_,_ , sol_plain_hat_30 = oracle_30.solve_plain(b_hat_30)
_, _,  sol_foil_hat_30 = oracle_30.solve_foil(b_hat_30)

plot_bs_results(
    DATA_30, b0_30, b_hat_30,
    sol0=solF_30,
    sol_plain_hat=sol_plain_hat_30,
    sol_foil_hat=sol_foil_hat_30,
    res_bs=res_bs_30,
    label="IEEE 30-bus",
    foil_label=f"emissions −{ALPHA:.0%}",
)

# %% [markdown]
# ### 3.4 · IEEE 39-bus

# %%
# ── Branch-and-Sandwich — IEEE 39-bus ──────────────────────────────────────
assert solFoil_b0_39 is not None, \
    "Foil is infeasible at b0 for IEEE 39-bus — check emissions data."

def _make_emission_viol_fn_39():
    E_f  = E_factual_39
    tgt  = (1 - ALPHA) * E_f
    e_g  = e_39
    def viol_fn(m, var, idx):
        s = m.addVar(lb=0.0, name="emis_viol")
        total_emis = gp.quicksum(
            e_g[g] * var["p"][g, t]
            for g in range(len(e_g))
            for t in range(int(DATA_39.T))
        )
        m.addConstr(s >= (total_emis - tgt) / max(E_f, 1.0), name="emis_viol_constr")
        m.update()
        return s
    return viol_fn

viol_fn_39 = _make_emission_viol_fn_39()

bs_39 = UCBranchAndSandwichWCE_4b(
    oracle=oracle_39,
    data=DATA_39, idx=idx_39, cvec=cvec_39,
    foil_extra_constr_fn=foil_fn_39,
    b0=b0_39,
    b_bounds=(bL_39, bU_39),
    b_free_idx=b_free_idx_39,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_39,
    foil_violation_expr_fn=viol_fn_39,
    lagrange_penalty=550.0,
)

res_bs_39 = bs_39.run(
    window_size=int(DATA_39.T),
    per_bus_neutrality=True,
    u_init=u_init_39, p_init=p_init_39,
    on_t=on_t_39, off_t=off_t_39,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\nIEEE 39-bus  certified={res_bs_39['certified']}  "
      f"gap={res_bs_39.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_39.get('nodes')}")
# Out:
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [INC] b_max: F=1890.3387 v=48559.190 v_D=48559.190
#   [INNER_UB] tightened by incumbent: 48559.1903
# [BS] node=0000 olb=0.0000 inner=[27116.54,78680.20] bestF=1890.3387 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [INC] node=0000: F=945.1693 v=48559.190 v_D=48559.190
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [INC] node=0000: F=41.0160 v=65175.122 v_D=65175.122
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [LAG_OLB] DISCARDED (lag=535.9473 > bestF=41.0160)
# [BS] node=0001 olb=0.0000 inner=[27116.54,78680.20] bestF=41.0160 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [LAG_OLB] DISCARDED (lag=267.9736 > bestF=41.0160)
# [BS] node=0003 olb=0.0000 inner=[27116.54,78680.20] bestF=41.0160 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [LAG_OLB] DISCARDED (lag=158.1886 > bestF=41.0160)
# [BS] node=0005 olb=0.0000 inner=[27116.54,78680.20] bestF=41.0160 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [LAG_OLB] DISCARDED (lag=133.9868 > bestF=41.0160)
# [BS] node=0007 olb=0.0000 inner=[27116.54,78680.20] bestF=41.0160 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [LAG_OLB] DISCARDED (lag=82.0321 > bestF=41.0160)
# [BS] node=0009 olb=0.0000 inner=[27116.54,78680.20] bestF=41.0160 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [INC] node=0009: F=20.5080 v=65175.122 v_D=65175.122
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71779.022274 + eps
#   [LAG_OLB] DISCARDED (lag=79.0943 > bestF=20.5080)
# [BS] node=0011 olb=0.0000 inner=[27116.54,78680.20] bestF=20.5080 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72792.266269 > v=72079.952095 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [LAG_OLB] DISCARDED (lag=66.9934 > bestF=20.5080)
# [BS] node=0013 olb=0.0000 inner=[27116.54,78680.20] bestF=20.5080 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72792.266269 > v=72079.952095 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [LAG_OLB] DISCARDED (lag=48.1345 > bestF=20.5080)
# [BS] node=0015 olb=0.0000 inner=[27116.54,78680.20] bestF=20.5080 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72792.266269 > v=72079.952095 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [LAG_OLB] DISCARDED (lag=44.0668 > bestF=20.5080)
# [BS] node=0017 olb=0.0000 inner=[27116.54,78680.20] bestF=20.5080 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72792.266269 > v=72079.952095 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [LAG_OLB] DISCARDED (lag=41.0160 > bestF=20.5080)
# [BS] node=0019 olb=0.0000 inner=[27116.54,78680.20] bestF=20.5080 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [INC] node=0019: F=10.2540 v=65473.261 v_D=65473.261
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [weak_ok] FAIL: v_D=72792.266269 > v=72079.952095 + eps
#   [weak_ok] FAIL: v_D=72232.417634 > v=71790.130867 + eps
#   [LAG_OLB] DISCARDED (lag=39.5472 > bestF=10.2540)
# [BS] node=0021 olb=0.0000 inner=[27131.07,78680.20] bestF=10.2540 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87886.801573 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=77811.552929 > v=74600.391327 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [LAG_OLB] DISCARDED (lag=38.4000 > bestF=10.2540)
# [BS] node=0023 olb=0.0000 inner=[27131.07,78680.20] bestF=10.2540 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=77811.552929 > v=74600.391327 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [LAG_OLB] DISCARDED (lag=38.4000 > bestF=10.2540)
# [BS] node=0025 olb=0.0000 inner=[27131.07,78680.20] bestF=10.2540 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=77811.552929 > v=74600.391327 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [LAG_OLB] DISCARDED (lag=33.4967 > bestF=10.2540)
# [BS] node=0027 olb=0.0000 inner=[27131.07,78680.20] bestF=10.2540 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=77811.552929 > v=74600.391327 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [LAG_OLB] DISCARDED (lag=24.0673 > bestF=10.2540)
# [BS] node=0029 olb=0.0000 inner=[27131.07,78680.20] bestF=10.2540 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=77811.552929 > v=74600.391327 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [LAG_OLB] DISCARDED (lag=22.0334 > bestF=10.2540)
# [BS] node=0031 olb=0.0000 inner=[27131.07,78680.20] bestF=10.2540 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=77811.552929 > v=74600.391327 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [LAG_OLB] DISCARDED (lag=20.5080 > bestF=10.2540)
# [BS] node=0033 olb=0.0000 inner=[27131.07,78680.20] bestF=10.2540 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [INC] node=0033: F=5.1270 v=68676.344 v_D=68676.344
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [weak_ok] FAIL: v_D=77811.552929 > v=74600.391327 + eps
#   [weak_ok] FAIL: v_D=75214.887154 > v=73463.456335 + eps
#   [LAG_OLB] DISCARDED (lag=19.7736 > bestF=5.1270)
# [BS] node=0035 olb=0.0000 inner=[27395.53,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=84447.527300 > v=76626.081201 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [LAG_OLB] DISCARDED (lag=19.2000 > bestF=5.1270)
# [BS] node=0037 olb=0.0000 inner=[27395.53,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=84447.527300 > v=76626.081201 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [LAG_OLB] DISCARDED (lag=19.2000 > bestF=5.1270)
# [BS] node=0039 olb=0.0000 inner=[27395.53,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=84447.527300 > v=76626.081201 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [LAG_OLB] DISCARDED (lag=16.7484 > bestF=5.1270)
# [BS] node=0041 olb=0.0000 inner=[27395.53,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=84447.527300 > v=76626.081201 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [LAG_OLB] DISCARDED (lag=12.0336 > bestF=5.1270)
# [BS] node=0043 olb=0.0000 inner=[28276.62,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=84447.527300 > v=76626.081201 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [LAG_OLB] DISCARDED (lag=11.0167 > bestF=5.1270)
# [BS] node=0045 olb=0.0000 inner=[28276.62,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101540.036371 > v=76908.117143 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=84447.527300 > v=76626.081201 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [LAG_OLB] DISCARDED (lag=10.2540 > bestF=5.1270)
# [BS] node=0047 olb=0.0000 inner=[28775.33,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72510.391156 > v=71851.798938 + eps
#   [weak_ok] FAIL: v_D=101540.036371 > v=76908.117143 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [weak_ok] FAIL: v_D=84447.527300 > v=76626.081201 + eps
#   [weak_ok] FAIL: v_D=81927.297185 > v=75820.541436 + eps
#   [LAG_OLB] DISCARDED (lag=9.8868 > bestF=5.1270)
# [BS] node=0049 olb=0.0000 inner=[29252.24,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72510.391156 > v=71851.798938 + eps
#   [weak_ok] FAIL: v_D=101540.036371 > v=76908.117143 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=97269.569596 > v=78377.515605 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=90078.627874 > v=77772.156373 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [LAG_OLB] DISCARDED (lag=9.6000 > bestF=5.1270)
# [BS] node=0051 olb=0.0000 inner=[29252.24,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=88041.078458 > v=77154.720364 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72510.391156 > v=71851.798938 + eps
#   [weak_ok] FAIL: v_D=101540.036371 > v=76908.117143 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=97269.569596 > v=78377.515605 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=90078.627874 > v=77772.156373 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [LAG_OLB] DISCARDED (lag=9.6000 > bestF=5.1270)
# [BS] node=0053 olb=0.0000 inner=[29252.24,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=88041.078458 > v=77154.720364 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72510.391156 > v=71851.798938 + eps
#   [weak_ok] FAIL: v_D=101540.036371 > v=76908.117143 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=97269.569596 > v=78377.515605 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=90078.627874 > v=77772.156373 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [LAG_OLB] DISCARDED (lag=8.3742 > bestF=5.1270)
# [BS] node=0055 olb=0.0000 inner=[29252.24,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=88041.078458 > v=77154.720364 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=72510.391156 > v=71851.798938 + eps
#   [weak_ok] FAIL: v_D=101540.036371 > v=76908.117143 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75795.823103 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101539.753983 > v=75604.856201 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=97269.569596 > v=78377.515605 + eps
#   [weak_ok] FAIL: v_D=93425.674955 > v=78074.835989 + eps
#   [weak_ok] FAIL: v_D=90078.627874 > v=77772.156373 + eps
#   [weak_ok] FAIL: v_D=87766.072168 > v=77471.650563 + eps
#   [LAG_OLB] DISCARDED (lag=6.0168 > bestF=5.1270)
# [BS] node=0057 olb=0.0000 inner=[31102.66,78680.20] bestF=5.1270 gLB=0.0000 gap=100.0%
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78177.755301 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77714.451175 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=77589.674214 + eps
#   [weak_ok] FAIL: v_D=88041.078458 > v=77154.720364 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=87881.647766 > v=77129.565034 + eps
#   [weak_ok] FAIL: v_D=101555.419062 > v=78680.195221 + eps
# ...
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=94374.037476 > v=78190.287218 + eps
#   [weak_ok] FAIL: v_D=90008.868754 > v=77775.147673 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426759 + eps
#   [weak_ok] FAIL: v_D=99849.349034 > v=78586.734648 + eps
#   [weak_ok] FAIL: v_D=99488.964247 > v=78568.042533 + eps
#   [weak_ok] FAIL: v_D=99185.561703 > v=78549.350419 + eps
#   [weak_ok] FAIL: v_D=98911.789180 > v=78530.658304 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=97655.321439 > v=78440.428349 + eps
#   [weak_ok] FAIL: v_D=95185.358829 > v=78275.429935 + eps
#   [weak_ok] FAIL: v_D=92974.272405 > v=78110.431521 + eps
#   [weak_ok] FAIL: v_D=90775.272083 > v=77946.438279 + eps
#   [weak_ok] FAIL: v_D=100209.062209 > v=78591.006257 + eps
#   [weak_ok] FAIL: v_D=100208.390597 > v=78576.585751 + eps
#   [weak_ok] FAIL: v_D=100207.718984 > v=78562.165245 + eps
#   [weak_ok] FAIL: v_D=100207.047371 > v=78547.744740 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100064.083369 > v=78595.968025 + eps
#   [weak_ok] FAIL: v_D=99918.432916 > v=78586.509287 + eps
#   [weak_ok] FAIL: v_D=99772.782463 > v=78577.050549 + eps
#   [weak_ok] FAIL: v_D=99627.132010 > v=78567.591811 + eps
# [BS] node=0723 olb=0.4130 inner=[37430.11,78605.43] bestF=5.1270 gLB=0.4145 gap=91.9%
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=94374.037476 > v=78190.287218 + eps
#   [weak_ok] FAIL: v_D=90008.868754 > v=77775.147673 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426759 + eps
#   [weak_ok] FAIL: v_D=99849.349034 > v=78586.734648 + eps
#   [weak_ok] FAIL: v_D=99488.964247 > v=78568.042533 + eps
#   [weak_ok] FAIL: v_D=99185.561703 > v=78549.350419 + eps
#   [weak_ok] FAIL: v_D=98911.789180 > v=78530.658304 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=97655.321439 > v=78440.428349 + eps
#   [weak_ok] FAIL: v_D=95185.358829 > v=78275.429935 + eps
#   [weak_ok] FAIL: v_D=92974.272405 > v=78110.431521 + eps
#   [weak_ok] FAIL: v_D=90775.272083 > v=77946.438279 + eps
#   [weak_ok] FAIL: v_D=100209.062209 > v=78591.006257 + eps
#   [weak_ok] FAIL: v_D=100208.390597 > v=78576.585751 + eps
#   [weak_ok] FAIL: v_D=100207.718984 > v=78562.165245 + eps
#   [weak_ok] FAIL: v_D=100207.047371 > v=78547.744740 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100209.733822 > v=78605.426763 + eps
#   [weak_ok] FAIL: v_D=100064.083369 > v=78595.968025 + eps
#   [weak_ok] FAIL: v_D=99918.432916 > v=78586.509287 + eps
#   [weak_ok] FAIL: v_D=99772.782463 > v=78577.050549 + eps
#   [weak_ok] FAIL: v_D=99627.132010 > v=78567.591811 + eps
# [BS] node=0424 olb=0.4145 inner=[37387.27,77369.90] bestF=5.1270 gLB=0.4153 gap=91.9%
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=84951.664741 > v=76893.629696 + eps
#   [weak_ok] FAIL: v_D=82632.106136 > v=76441.379257 + eps
#   [weak_ok] FAIL: v_D=87306.471657 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87290.624853 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87274.778049 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87258.931245 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87153.356039 > v=77332.512777 + eps
#   [weak_ok] FAIL: v_D=86984.393618 > v=77295.374143 + eps
#   [weak_ok] FAIL: v_D=86815.431197 > v=77258.432906 + eps
#   [weak_ok] FAIL: v_D=86646.468776 > v=77221.491669 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=86385.232529 > v=77208.052981 + eps
#   [weak_ok] FAIL: v_D=85448.180493 > v=77046.849770 + eps
#   [weak_ok] FAIL: v_D=84514.250043 > v=76888.768146 + eps
#   [weak_ok] FAIL: v_D=83591.287467 > v=76741.654396 + eps
#   [weak_ok] FAIL: v_D=87316.009608 > v=77340.100349 + eps
#   [weak_ok] FAIL: v_D=87309.700756 > v=77310.303691 + eps
#   [weak_ok] FAIL: v_D=87303.391903 > v=77280.507034 + eps
#   [weak_ok] FAIL: v_D=87297.083051 > v=77250.710376 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87265.681015 > v=77360.438269 + eps
#   [weak_ok] FAIL: v_D=87209.077466 > v=77350.979531 + eps
#   [weak_ok] FAIL: v_D=87152.473917 > v=77341.520793 + eps
#   [weak_ok] FAIL: v_D=87095.870368 > v=77332.062055 + eps
# [BS] node=0725 olb=0.4145 inner=[37387.27,77369.90] bestF=5.1270 gLB=0.4153 gap=91.9%
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=84957.973594 > v=76923.606036 + eps
#   [weak_ok] FAIL: v_D=82645.202468 > v=76501.331936 + eps
#   [weak_ok] FAIL: v_D=87306.471657 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87290.624853 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87274.778049 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87258.931245 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87153.356039 > v=77332.512777 + eps
#   [weak_ok] FAIL: v_D=86984.393618 > v=77295.374143 + eps
#   [weak_ok] FAIL: v_D=86815.431197 > v=77258.432906 + eps
#   [weak_ok] FAIL: v_D=86646.468776 > v=77221.491669 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=86385.232529 > v=77208.052981 + eps
#   [weak_ok] FAIL: v_D=85448.180493 > v=77046.849770 + eps
#   [weak_ok] FAIL: v_D=84514.250043 > v=76888.768146 + eps
#   [weak_ok] FAIL: v_D=83591.287467 > v=76741.654396 + eps
#   [weak_ok] FAIL: v_D=87319.164034 > v=77354.998678 + eps
#   [weak_ok] FAIL: v_D=87316.009608 > v=77340.100349 + eps
#   [weak_ok] FAIL: v_D=87312.855182 > v=77325.202020 + eps
#   [weak_ok] FAIL: v_D=87309.700756 > v=77310.303691 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87265.681015 > v=77360.438269 + eps
#   [weak_ok] FAIL: v_D=87209.077466 > v=77350.979531 + eps
#   [weak_ok] FAIL: v_D=87152.473917 > v=77341.520793 + eps
#   [weak_ok] FAIL: v_D=87095.870368 > v=77332.062055 + eps
# [BS] node=0727 olb=0.4145 inner=[37387.27,77369.90] bestF=5.1270 gLB=0.4153 gap=91.9%
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=85126.936015 > v=76960.547273 + eps
#   [weak_ok] FAIL: v_D=82964.411521 > v=76564.719232 + eps
#   [weak_ok] FAIL: v_D=87306.471657 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87290.624853 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87274.778049 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87258.931245 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87237.837250 > v=77351.204892 + eps
#   [weak_ok] FAIL: v_D=87153.356039 > v=77332.512777 + eps
#   [weak_ok] FAIL: v_D=87068.874829 > v=77313.844762 + eps
#   [weak_ok] FAIL: v_D=86984.393618 > v=77295.374143 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=86385.232529 > v=77208.052981 + eps
#   [weak_ok] FAIL: v_D=85448.180493 > v=77046.849770 + eps
#   [weak_ok] FAIL: v_D=84514.250043 > v=76888.768146 + eps
#   [weak_ok] FAIL: v_D=83591.287467 > v=76741.654396 + eps
#   [weak_ok] FAIL: v_D=87319.164034 > v=77354.998678 + eps
#   [weak_ok] FAIL: v_D=87316.009608 > v=77340.100349 + eps
#   [weak_ok] FAIL: v_D=87312.855182 > v=77325.202020 + eps
#   [weak_ok] FAIL: v_D=87309.700756 > v=77310.303691 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87265.681015 > v=77360.438269 + eps
#   [weak_ok] FAIL: v_D=87209.077466 > v=77350.979531 + eps
#   [weak_ok] FAIL: v_D=87152.473917 > v=77341.520793 + eps
#   [weak_ok] FAIL: v_D=87095.870368 > v=77332.062055 + eps
# [BS] node=0729 olb=0.4145 inner=[37387.27,77369.90] bestF=5.1270 gLB=0.4153 gap=91.9%
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=85126.936015 > v=76960.547273 + eps
#   [weak_ok] FAIL: v_D=82964.411521 > v=76564.719232 + eps
#   [weak_ok] FAIL: v_D=87306.471657 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87290.624853 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87274.778049 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87258.931245 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87237.837250 > v=77351.204892 + eps
#   [weak_ok] FAIL: v_D=87153.356039 > v=77332.512777 + eps
#   [weak_ok] FAIL: v_D=87068.874829 > v=77313.844762 + eps
#   [weak_ok] FAIL: v_D=86984.393618 > v=77295.374143 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=86385.232529 > v=77208.052981 + eps
#   [weak_ok] FAIL: v_D=85448.180493 > v=77046.849770 + eps
#   [weak_ok] FAIL: v_D=84514.250043 > v=76888.768146 + eps
#   [weak_ok] FAIL: v_D=83591.287467 > v=76741.654396 + eps
#   [weak_ok] FAIL: v_D=87319.164034 > v=77354.998678 + eps
#   [weak_ok] FAIL: v_D=87316.009608 > v=77340.100349 + eps
#   [weak_ok] FAIL: v_D=87312.855182 > v=77325.202020 + eps
#   [weak_ok] FAIL: v_D=87309.700756 > v=77310.303691 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87322.318460 > v=77369.897007 + eps
#   [weak_ok] FAIL: v_D=87265.681015 > v=77360.438269 + eps
#   [weak_ok] FAIL: v_D=87209.077466 > v=77350.979531 + eps
#   [weak_ok] FAIL: v_D=87152.473917 > v=77341.520793 + eps
#   [weak_ok] FAIL: v_D=87095.870368 > v=77332.062055 + eps
# [BS] node=0496 olb=0.4153 inner=[37444.76,77887.75] bestF=5.1270 gLB=0.4153 gap=91.9%
#   [weak_ok] FAIL: v_D=90758.414789 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=88516.387775 > v=77475.091735 + eps
#   [weak_ok] FAIL: v_D=86329.452731 > v=77063.338507 + eps
#   [weak_ok] FAIL: v_D=90747.526842 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=90744.450445 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=90744.450445 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=90744.450445 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=90656.788770 > v=77869.058969 + eps
#   [weak_ok] FAIL: v_D=90561.652461 > v=77850.366854 + eps
#   [weak_ok] FAIL: v_D=90469.220295 > v=77831.674740 + eps
#   [weak_ok] FAIL: v_D=90374.312158 > v=77812.982625 + eps
#   [weak_ok] FAIL: v_D=90758.414789 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=90758.414789 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=90758.414789 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=90758.414789 > v=77887.751083 + eps
#   [weak_ok] FAIL: v_D=89767.228014 > v=77724.017531 + eps
#   [weak_ok] FAIL: v_D=88835.864438 > v=77561.190098 + eps
#   [weak_ok] FAIL: v_D=87904.500861 > v=77398.362665 + eps
#   [weak_ok] FAIL: v_D=86971.775914 > v=77235.535233 + eps
#   [weak_ok] FAIL: v_D=90753.240624 > v=77873.330578 + eps
#   [weak_ok] FAIL: v_D=90749.345913 > v=77858.910072 + eps
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[14], line 43
#      21 viol_fn_39 = _make_emission_viol_fn_39()
#      23 bs_39 = UCBranchAndSandwichWCE_4b(
#      24     oracle=oracle_39,
#      25     data=DATA_39, idx=idx_39, cvec=cvec_39,
#    (...)
#      40     lagrange_penalty=550.0,
#      41 )
# ---> 43 res_bs_39 = bs_39.run(
#      44     window_size=int(DATA_39.T),
#      45     per_bus_neutrality=True,
#      46     u_init=u_init_39, p_init=p_init_39,
#      47     on_t=on_t_39, off_t=off_t_39,
#      48     compute_final_mip_lb=True,
#      49     mip_lb_time_limit=3600.0,
#      50 )
#      52 print(f"\nIEEE 39-bus  certified={res_bs_39['certified']}  "
#      53       f"gap={res_bs_39.get('gap', float('nan')):.4f}  "
#      54       f"nodes={res_bs_39.get('nodes')}")
#
# File c:\Users\tomas\Documents\GitHub\Counterfactual-Explanations-for-optimization-problems\Mixed\UC-Experiments\uc_branch_sandwich_4b.py:679, in UCBranchAndSandwichWCE_4b.run(self, window_size, per_bus_neutrality, u_init, p_init, on_t, off_t, compute_final_mip_lb, mip_lb_time_limit)
#     677 any_oub_ok = False
#     678 for b in self._oub_candidates(node):
# --> 679     ok, vp, vD = self.weak_ok(b)
#     680     if ok:
#     681         any_oub_ok = True
#
# File c:\Users\tomas\Documents\GitHub\Counterfactual-Explanations-for-optimization-problems\Mixed\UC-Experiments\uc_branch_sandwich_4b.py:157, in UCBranchAndSandwichWCE_4b.weak_ok(self, b)
#     155 def weak_ok(self, b):
#     156     v_plain, _, _ = self.oracle.solve_plain(b)
# --> 157     v_foil,  _, _ = self.oracle.solve_foil(b)
#     158     if v_plain is None or v_foil is None:
#     159         return False, v_plain, v_foil
#
# Cell In[2], line 98, in UCWeakWCEOracle.solve_foil(self, b_line)
#      97 def solve_foil(self, b_line):
# ---> 98     return self._solve(b_line, self.foil_extra_constr_fn, self.cache_foil)
#
# Cell In[2], line 79, in UCWeakWCEOracle._solve(self, b_line, extra_fn, cache)
#      77     return cache[key]
#      78 data_b = replace_line_limits(self.data, b_line)
# ---> 79 m, sol, z = solve_uc_with_cost_4b(
#      80     data=data_b, idx=self.idx, cvec=self.cvec,
#      81     window_size=self.window_size,
#      82     per_bus_neutrality=self.per_bus_neutrality,
#      83     u_init=self.u_init, p_init=self.p_init,
#      84     on_time_init=self.on_t, off_time_init=self.off_t,
#      85     extra_constr_fn=extra_fn,
#      86     output_flag=self.output_flag,
#      87     time_limit=self.time_limit,
#      88     fmax_override=None,
#      89 )
#      90 out = (None, None, None) if sol is None else (float(sol["obj"]), np.array(z, float), sol)
#      91 cache[key] = out
#
# File c:\Users\tomas\Documents\GitHub\Counterfactual-Explanations-for-optimization-problems\Mixed\UC-Experiments\uc_pipeline.py:794, in solve_uc_with_cost_4b(data, idx, cvec, window_size, per_bus_neutrality, u_init, p_init, on_time_init, off_time_init, extra_constr_fn, output_flag, time_limit, fmax_override)
#     791 if time_limit is not None:
#     792     m.Params.TimeLimit = float(time_limit)
# --> 794 m.optimize()
#     796 if m.Status != GRB.OPTIMAL:
#     797     return m, None, None
#
# File src/gurobipy/_model.pyx:926, in gurobipy._model.Model.optimize()
#
# GurobiError: Could not resolve host: token.gurobi.com (code 6, command POST https://token.gurobi.com/api/v1/tokens)

# %%
# ── Plot — IEEE 39-bus ──────────────────────────────────────────────────────
assert res_bs_39.get("success") and res_bs_39.get("b_hat") is not None, \
    "No incumbent for IEEE 39-bus."

b_hat_39 = np.array(res_bs_39["b_hat"], dtype=float)

_,_ , sol_plain_hat_39 = oracle_39.solve_plain(b_hat_39)
_, _,  sol_foil_hat_39  = oracle_39.solve_foil(b_hat_39)

plot_bs_results(
    DATA_39, b0_39, b_hat_39,
    sol0=solF_39,
    sol_plain_hat=sol_plain_hat_39,
    sol_foil_hat=sol_foil_hat_39,
    res_bs=res_bs_39,
    label="IEEE 39-bus",
    foil_label=f"emissions −{ALPHA:.0%}",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # ── Plot — IEEE 39-bus ──────────────────────────────────────────────────────
# ----> 2 assert res_bs_39.get("success") and res_bs_39.get("b_hat") is not None, \
#       3     "No incumbent for IEEE 39-bus."
#       5 b_hat_39 = np.array(res_bs_39["b_hat"], dtype=float)
#       7 _,_ , sol_plain_hat_39 = oracle_39.solve_plain(b_hat_39)
#
# NameError: name 'res_bs_39' is not defined

# %% [markdown]
# ### 3.5 · IEEE 57-bus

# %%
# ── Branch-and-Sandwich — IEEE 57-bus ──────────────────────────────────────
assert solFoil_b0_57 is not None, \
    "Foil is infeasible at b0 for IEEE 57-bus — check emissions data."

def _make_emission_viol_fn_57():
    E_f  = E_factual_57
    tgt  = (1 - ALPHA) * E_f
    e_g  = e_57
    def viol_fn(m, var, idx):
        s = m.addVar(lb=0.0, name="emis_viol")
        total_emis = gp.quicksum(
            e_g[g] * var["p"][g, t]
            for g in range(len(e_g))
            for t in range(int(DATA_57.T))
        )
        m.addConstr(s >= (total_emis - tgt) / max(E_f, 1.0), name="emis_viol_constr")
        m.update()
        return s
    return viol_fn

viol_fn_57 = _make_emission_viol_fn_57()

bs_57 = UCBranchAndSandwichWCE_4b(
    oracle=oracle_57,
    data=DATA_57, idx=idx_57, cvec=cvec_57,
    foil_extra_constr_fn=foil_fn_57,
    b0=b0_57,
    b_bounds=(bL_57, bU_57),
    b_free_idx=b_free_idx_57,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_57,
    foil_violation_expr_fn=viol_fn_57,
    lagrange_penalty=200.0,
)

res_bs_57 = bs_57.run(
    window_size=int(DATA_57.T),
    per_bus_neutrality=True,
    u_init=u_init_57, p_init=p_init_57,
    on_t=on_t_57, off_t=off_t_57,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\nIEEE 57-bus  certified={res_bs_57['certified']}  "
      f"gap={res_bs_57.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_57.get('nodes')}")

# %%
# ── Plot — IEEE 57-bus ──────────────────────────────────────────────────────
assert res_bs_57.get("success") and res_bs_57.get("b_hat") is not None, \
    "No incumbent for IEEE 57-bus."

b_hat_57 = np.array(res_bs_57["b_hat"], dtype=float)

_,_ , sol_plain_hat_57 = oracle_57.solve_plain(b_hat_57)
_, _,  sol_foil_hat_57  = oracle_57.solve_foil(b_hat_57)

plot_bs_results(
    DATA_57, b0_57, b_hat_57,
    sol0=solF_57,
    sol_plain_hat=sol_plain_hat_57,
    sol_foil_hat=sol_foil_hat_57,
    res_bs=res_bs_57,
    label="IEEE 57-bus",
    foil_label=f"emissions −{ALPHA:.0%}",
)

# %% [markdown]
# ### 3.6 · IEEE 118-bus

# %%
# ── Branch-and-Sandwich — IEEE 118-bus ──────────────────────────────────────
assert solFoil_b0_118 is not None, \
    "Foil is infeasible at b0 for IEEE 118-bus — check emissions data."

def _make_emission_viol_fn_118():
    E_f  = E_factual_118
    tgt  = (1 - ALPHA) * E_f
    e_g  = e_118
    def viol_fn(m, var, idx):
        s = m.addVar(lb=0.0, name="emis_viol")
        total_emis = gp.quicksum(
            e_g[g] * var["p"][g, t]
            for g in range(len(e_g))
            for t in range(int(DATA_118.T))
        )
        m.addConstr(s >= (total_emis - tgt) / max(E_f, 1.0), name="emis_viol_constr")
        m.update()
        return s
    return viol_fn

viol_fn_118 = _make_emission_viol_fn_118()

bs_118 = UCBranchAndSandwichWCE_4b(
    oracle=oracle_118,
    data=DATA_118, idx=idx_118, cvec=cvec_118,
    foil_extra_constr_fn=foil_fn_118,
    b0=b0_118,
    b_bounds=(bL_118, bU_118),
    b_free_idx=b_free_idx_118,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_118,
    foil_violation_expr_fn=viol_fn_118,
    lagrange_penalty=200.0,
)

res_bs_118 = bs_118.run(
    window_size=int(DATA_118.T),
    per_bus_neutrality=True,
    u_init=u_init_118, p_init=p_init_118,
    on_t=on_t_118, off_t=off_t_118,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\nIEEE 118-bus  certified={res_bs_118['certified']}  "
      f"gap={res_bs_118.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_118.get('nodes')}")

# %%
# ── Plot — IEEE 118-bus ──────────────────────────────────────────────────────
assert res_bs_118.get("success") and res_bs_118.get("b_hat") is not None, \
    "No incumbent for IEEE 118-bus."

b_hat_118 = np.array(res_bs_118["b_hat"], dtype=float)

_,_ ,sol_plain_hat_118, _ = oracle_118.solve_plain(b_hat_118)
_, _,  sol_foil_hat_118  = oracle_118.solve_foil(b_hat_118)

plot_bs_results(
    DATA_118, b0_118, b_hat_118,
    sol0=solF_118,
    sol_plain_hat=sol_plain_hat_118,
    sol_foil_hat=sol_foil_hat_118,
    res_bs=res_bs_118,
    label="IEEE 118-bus",
    foil_label=f"emissions −{ALPHA:.0%}",
)

# %% [markdown]
# ### 3.7 · IEEE 300-bus

# %%
# ── Branch-and-Sandwich — IEEE 300-bus ──────────────────────────────────────
assert solFoil_b0_300 is not None, \
    "Foil is infeasible at b0 for IEEE 300-bus — check emissions data."

def _make_emission_viol_fn_300():
    E_f  = E_factual_300
    tgt  = (1 - ALPHA) * E_f
    e_g  = e_300
    def viol_fn(m, var, idx):
        s = m.addVar(lb=0.0, name="emis_viol")
        total_emis = gp.quicksum(
            e_g[g] * var["p"][g, t]
            for g in range(len(e_g))
            for t in range(int(DATA_300.T))
        )
        m.addConstr(s >= (total_emis - tgt) / max(E_f, 1.0), name="emis_viol_constr")
        m.update()
        return s
    return viol_fn

viol_fn_300 = _make_emission_viol_fn_300()

bs_300 = UCBranchAndSandwichWCE_4b(
    oracle=oracle_300,
    data=DATA_300, idx=idx_300, cvec=cvec_300,
    foil_extra_constr_fn=foil_fn_300,
    b0=b0_300,
    b_bounds=(bL_300, bU_300),
    b_free_idx=b_free_idx_300,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_300,
    foil_violation_expr_fn=viol_fn_300,
    lagrange_penalty=200.0,
)

res_bs_300 = bs_300.run(
    window_size=int(DATA_300.T),
    per_bus_neutrality=True,
    u_init=u_init_300, p_init=p_init_300,
    on_t=on_t_300, off_t=off_t_300,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\nIEEE 300-bus  certified={res_bs_300['certified']}  "
      f"gap={res_bs_300.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_300.get('nodes')}")

# %%
# ── Plot — IEEE 300-bus ──────────────────────────────────────────────────────
assert res_bs_300.get("success") and res_bs_300.get("b_hat") is not None, \
    "No incumbent for IEEE 300-bus."

b_hat_300 = np.array(res_bs_300["b_hat"], dtype=float)

_,_, sol_plain_hat_300, _ = oracle_300.solve_plain(b_hat_300)
_, _,  sol_foil_hat_300  = oracle_300.solve_foil(b_hat_300)

plot_bs_results(
    DATA_300, b0_300, b_hat_300,
    sol0=solF_300,
    sol_plain_hat=sol_plain_hat_300,
    sol_foil_hat=sol_foil_hat_300,
    res_bs=res_bs_300,
    label="IEEE 300-bus",
    foil_label=f"emissions −{ALPHA:.0%}",
)

# %% [markdown]
# ### Bonus · 6-bus — commitment-flip foil
#
# Run B&S on the 6-bus grid a second time using the best **commitment-flip foil**
# (force generator ON/OFF) found by `scan_foil_candidates`.
# This allows direct comparison with the emissions foil above.

# %%
# ── Scan commitment-flip foil candidates — 6-bus ─────────────────────────
candidates_6_flip = scan_foil_candidates(
    data=DATA_6, idx=idx_6, cvec=cvec_6,
    solF=solF_6, zF=zF_6,
    window_size=int(DATA_6.T), per_bus_neutrality=True,
    u_init=u_init_6, p_init=p_init_6,
    on_t=on_t_6, off_t=off_t_6,
    min_gap=100, max_gap=1e7, block_len_range=(2, 4),
)

if candidates_6_flip:
    best_gap_6f, best_g_6f, best_times_6f, best_type_6f = candidates_6_flip[0]
    foil_fn_6_flip = (foil_force_on(g=best_g_6f, times=best_times_6f)
                      if best_type_6f == "ON"
                      else foil_force_off(g=best_g_6f, times=best_times_6f))
    print(f"Selected commitment-flip foil: G{best_g_6f} {best_type_6f} "
          f"at t={best_times_6f}  gap={best_gap_6f:.0f}")
else:
    print("No commitment-flip foil found for 6-bus — adjust min_gap/max_gap.")
    foil_fn_6_flip = None

# %%
# ── B&S with commitment-flip foil — 6-bus ────────────────────────────────
assert foil_fn_6_flip is not None, "No commitment-flip foil available — run cell above."

oracle_6_flip = UCWeakWCEOracle(
    data=DATA_6, cvec=cvec_6, idx=idx_6,
    window_size=int(DATA_6.T), per_bus_neutrality=True,
    u_init=u_init_6, p_init=p_init_6, on_t=on_t_6, off_t=off_t_6,
    foil_extra_constr_fn=foil_fn_6_flip,
    output_flag=0, time_limit=None, cache_decimals=3,
)

# Verify foil feasibility at b0
vF_6f, _, solFoil_6f_b0 = oracle_6_flip.solve_foil(b0_6)
assert solFoil_6f_b0 is not None, "Commitment-flip foil is infeasible at b0 for 6-bus."

# Violation function for commitment-flip foil (objective distance proxy)
def viol_fn_6_flip(m, var, idx):
    """No soft-violation structure needed — commitment flip is already binary.
    Use a constant-zero slack (B&S will rely purely on feasibility checks)."""
    s = m.addVar(lb=0.0, ub=0.0, name="flip_viol_zero")
    m.update()
    return s

bs_6_flip = UCBranchAndSandwichWCE_4b(
    oracle=oracle_6_flip,
    data=DATA_6, idx=idx_6, cvec=cvec_6,
    foil_extra_constr_fn=foil_fn_6_flip,
    b0=b0_6,
    b_bounds=(bL_6, bU_6),
    b_free_idx=b_free_idx_6,
    eps_b=1.0,
    eps_obj=1e-3,
    eps_weak=1e-3,
    max_nodes=maxnodes,
    relax_cost_ub=None,
    master_time_limit=None,
    output_flag=0,
    verbose=True,
    w=w_6,
    foil_violation_expr_fn=viol_fn_6_flip,
    lagrange_penalty=200.0,
)

res_bs_6_flip = bs_6_flip.run(
    window_size=int(DATA_6.T),
    per_bus_neutrality=True,
    u_init=u_init_6, p_init=p_init_6,
    on_t=on_t_6, off_t=off_t_6,
    compute_final_mip_lb=True,
    mip_lb_time_limit=3600.0,
)

print(f"\n6-bus (commitment flip)  certified={res_bs_6_flip['certified']}  "
      f"gap={res_bs_6_flip.get('gap', float('nan')):.4f}  "
      f"nodes={res_bs_6_flip.get('nodes')}")

# %%
# ── Plot — 6-bus commitment-flip foil ────────────────────────────────────
assert res_bs_6_flip.get("success") and res_bs_6_flip.get("b_hat") is not None, \
    "No incumbent for 6-bus commitment-flip experiment."

b_hat_6_flip = np.array(res_bs_6_flip["b_hat"], dtype=float)

_, sol_plain_hat_6_flip, _ = oracle_6_flip.solve_plain(b_hat_6_flip)
_, sol_foil_hat_6_flip,  _ = oracle_6_flip.solve_foil(b_hat_6_flip)

flip_desc = f"G{best_g_6f} {best_type_6f} at t={best_times_6f}"
plot_bs_results(
    DATA_6, b0_6, b_hat_6_flip,
    sol0=solF_6,
    sol_plain_hat=sol_plain_hat_6_flip,
    sol_foil_hat=sol_foil_hat_6_flip,
    res_bs=res_bs_6_flip,
    label="6-bus (commitment flip)",
    foil_label=flip_desc,
)

# %% [markdown]
# ---
# ## Section 4 · Cross-grid comparison
#
# Summary table across all seven grids (emissions foil, α = 20 %).

# %%
print(f"{'Grid':<18} {'Free lines':>12} {'F_opt':>12} {'Gap %':>8} {'Nodes':>8} {'Certified':>10}")
print("\u2500" * 74)

grid_specs = [
    ("6-bus (WW)",   "6"),
    ("IEEE 14-bus",  "14"),
    ("IEEE 30-bus",  "30"),
    ("IEEE 39-bus",  "39"),
    ("IEEE 57-bus",  "57"),
    ("IEEE 118-bus", "118"),
    ("IEEE 300-bus", "300"),
]

for lbl, key in grid_specs:
    res   = eval(f"res_bs_{key}")
    b_fi  = eval(f"b_free_idx_{key}")
    F_opt = float(res.get("F_opt", float("nan")))
    LB    = res.get("global_LB", res.get("LB", float("nan")))
    LB    = float(LB) if LB is not None else float("nan")
    gap_pct = (100.0 * max(0.0, F_opt - LB) / abs(F_opt)
               if (np.isfinite(F_opt) and np.isfinite(LB) and abs(F_opt) > 1e-12)
               else float("nan"))
    nodes = res.get("nodes", "—")
    cert  = str(res.get("certified", "—"))
    print(f"{lbl:<18} {str(b_fi):>12} {F_opt:>12.4f} {gap_pct:>7.2f}% {str(nodes):>8} {cert:>10}")

print()
print("─── 6-bus commitment-flip comparison ───────────────────────────────")
res_f  = res_bs_6_flip
F_f    = float(res_f.get("F_opt", float("nan")))
LB_f   = float(res_f.get("global_LB", res_f.get("LB", float("nan"))) or float("nan"))
gap_f  = (100.0 * max(0.0, F_f - LB_f) / abs(F_f)
          if np.isfinite(F_f) and np.isfinite(LB_f) and abs(F_f) > 1e-12 else float("nan"))
F_e    = float(res_bs_6.get("F_opt", float("nan")))
print(f"  Emissions foil  F_opt = {F_e:.4f}")
print(f"  Commit-flip foil F_opt = {F_f:.4f}  gap={gap_f:.2f}%  "
      f"certified={res_f.get('certified')}")
